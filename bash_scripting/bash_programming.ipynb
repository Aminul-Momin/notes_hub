# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Bash-Refferences:" data-toc-modified-id="Bash-Refferences:-1">Bash Refferences:</a></span></li><li><span><a href="#Terminology:" data-toc-modified-id="Terminology:-2">Terminology:</a></span><ul class="toc-item"><li><span><a href="#The-Linux-Kernel" data-toc-modified-id="The-Linux-Kernel-2.1">The Linux Kernel</a></span></li><li><span><a href="#The-Shell" data-toc-modified-id="The-Shell-2.2">The Shell</a></span></li><li><span><a href="#Bash" data-toc-modified-id="Bash-2.3">Bash</a></span></li><li><span><a href="#Terminal" data-toc-modified-id="Terminal-2.4">Terminal</a></span></li></ul></li><li><span><a href="#Special-Variables-in-Bash:" data-toc-modified-id="Special-Variables-in-Bash:-3">Special Variables in Bash:</a></span></li><li><span><a href="#Shell-command-separator/control-characters:" data-toc-modified-id="Shell-command-separator/control-characters:-4">Shell command separator/control characters:</a></span></li><li><span><a href="#Elements-of-Bash:" data-toc-modified-id="Elements-of-Bash:-5">Elements of Bash:</a></span></li><li><span><a href="#Flags/Options-in-Bash:" data-toc-modified-id="Flags/Options-in-Bash:-6">Flags/Options in Bash:</a></span></li><li><span><a href="#Some-Discovered-Errors:" data-toc-modified-id="Some-Discovered-Errors:-7">Some Discovered Errors:</a></span></li><li><span><a href="#Control-Flow-in-Bash:" data-toc-modified-id="Control-Flow-in-Bash:-8">Control Flow in Bash:</a></span></li><li><span><a href="#Looping-in-Bash:" data-toc-modified-id="Looping-in-Bash:-9">Looping in Bash:</a></span><ul class="toc-item"><li><span><a href="#for:" data-toc-modified-id="for:-9.1">for:</a></span><ul class="toc-item"><li><span><a href="#Operating-on-a-file-list-contained-in-a-variable" data-toc-modified-id="Operating-on-a-file-list-contained-in-a-variable-9.1.1">Operating on a file list contained in a variable</a></span></li><li><span><a href="#Find-a-particular-string-in-the-binaries-in-a-specified-directory." data-toc-modified-id="Find-a-particular-string-in-the-binaries-in-a-specified-directory.-9.1.2">Find a particular string in the binaries in a specified directory.</a></span></li><li><span><a href="#Symbolic-links-in-a-directory,-saved-to-a-file" data-toc-modified-id="Symbolic-links-in-a-directory,-saved-to-a-file-9.1.3">Symbolic links in a directory, saved to a file</a></span></li><li><span><a href="#Nested-Loop" data-toc-modified-id="Nested-Loop-9.1.4">Nested Loop</a></span></li><li><span><a href="#Various-ways-of-geting-list-of-files's-path" data-toc-modified-id="Various-ways-of-geting-list-of-files's-path-9.1.5">Various ways of geting list of files's path</a></span></li></ul></li><li><span><a href="#while:" data-toc-modified-id="while:-9.2">while:</a></span><ul class="toc-item"><li><span><a href="#While-loop-with-multiple-conditions" data-toc-modified-id="While-loop-with-multiple-conditions-9.2.1">While loop with multiple conditions</a></span></li><li><span><a href="#Inside-its-test-brackets,-a-while-loop-can-call-a-function." data-toc-modified-id="Inside-its-test-brackets,-a-while-loop-can-call-a-function.-9.2.2">Inside its test brackets, a while loop can call a function.</a></span></li></ul></li></ul></li><li><span><a href="#Utilities-in-Bash:" data-toc-modified-id="Utilities-in-Bash:-10">Utilities in Bash:</a></span><ul class="toc-item"><li><span><a href="#find:" data-toc-modified-id="find:-10.1">find:</a></span></li><li><span><a href="#grep:" data-toc-modified-id="grep:-10.2">grep:</a></span></li><li><span><a href="#getopts" data-toc-modified-id="getopts-10.3"><a href="https://linuxhint.com/bash_getopts_example/" rel="nofollow" target="_blank">getopts</a></a></span><ul class="toc-item"><li><span><a href="#Tutorials:" data-toc-modified-id="Tutorials:-10.3.1">Tutorials:</a></span></li></ul></li><li><span><a href="#Stream-Editor:" data-toc-modified-id="Stream-Editor:-10.4">Stream Editor:</a></span><ul class="toc-item"><li><span><a href="#Substitution-command" data-toc-modified-id="Substitution-command-10.4.1">Substitution command</a></span></li><li><span><a href="#Other-sed-commands" data-toc-modified-id="Other-sed-commands-10.4.2">Other sed commands</a></span></li></ul></li><li><span><a href="#awk" data-toc-modified-id="awk-10.5"><a href="https://en.wikipedia.org/wiki/AWK" rel="nofollow" target="_blank">awk</a></a></span></li><li><span><a href="#Extended-Arguments:--xargs" data-toc-modified-id="Extended-Arguments:--xargs-10.6">Extended Arguments:  <a href="https://en.wikipedia.org/wiki/Xargs" rel="nofollow" target="_blank">xargs</a></a></span></li></ul></li></ul></div>

# %% [markdown]
# - <font color=magenta>**$ man bash**</font>
#     - print the manual of `Bash`

# %% [markdown]
# - [The 50 Most Popular Linux & Terminal Commands](https://www.youtube.com/watch?v=ZtqBQ68cfJc)
# - []()

# %% [markdown]
# ### Bash Refferences:

# %% [markdown]
# - [The Complete How To Guide Of Bash Functions](https://www.shell-tips.com/bash/functions/)
# - [Google Shell Style Guide](https://google.github.io/styleguide/shellguide.html)
# - [Interview Bit](https://www.interviewbit.com/shell-scripting-interview-questions/)
# - [Interview Questions](https://www.guru99.com/shell-scripting-interview-questions.html)

# %% [markdown]
# ### Terminology:

# %% [markdown]
# #### The Linux Kernel

# %% [markdown]
# Every operating system (OS) has a kernel. The kernel is the layer of the OS that bridges the hardware with the main programs that run on a computer. The kernel is the core of the OS and is the first to load when the computer boots up. It remains in the computer's memory throughout a session. It is responsible for providing an interface for all applications, controlling the hardware and allowing processes to get information from each other. There are three types of kernel:
#
# - Microkernel
# - Hybrid
# - Monolithic
#
# Linux uses a monolithic kernel, so called because it includes device drivers and the file management system and therefore requires more memory. On the opposite end of the spectrum, a microkernel aims to occupy the smallest amount of memory by managing only the necessities such as the CPU, memory and inter-process communication (IPC).

# %% [markdown]
# #### The Shell

# %% [markdown]
# The shell forms the layer between the user and the kernel so the user can enter commands. The kernel 'understands' only binary language, which is composed exclusively of ones and zeros. In early computing, any instructions/commands from the users were entered in binary language, but this evolved so that the user can enter commands in a more recognizable language. It is the shell that acts as the go-between, accepting the commands entered in the language recognizable by the user, and translating them to binary language for the kernel.

# %% [markdown]
# #### Bash

# %% [markdown]
# Bash stands for Bourne Again SHell, and is a type of shell found in Linux, which is the default shell in several versions ('distributions') of Linux. Other common types of shell are cshell and kshell, though there are others. The most primitive type of shell in Linux is sh.

# %% [markdown]
# #### Terminal

# %% [markdown]
# The terminal is the application that brings it all together, in the sense that it provides a visual representation of the shell for the user to enter commands. In other words, in a GUI (graphical user interface), where applications and other features are visually represented by images that the user can manipulate by clicking on them with a cursor, a terminal application opens a window where the user can type in commands for the shell to interpret into binary language for the kernel.
#
# Summing it all up, we could say that we've discussed three layers so far: the terminal, where the user enters written commands; the shell, and Bash being a type of shell, which takes those commands and interprets them into binary language; the kernel which takes the binary language commands and executes the task on hand.

# %% [markdown]
# ### Special Variables in Bash:

# %% [markdown]
# - `$0` $→$ The filename of the current script.
# - `$n` $→$ The Nth argument passed to script was invoked or function was called.
# - `$#` $→$ The number of argument passed to script or function.
# - `$@` $→$ All arguments passed to script or function.
# - `$*` $→$ All arguments passed to script or function.
# - `$?` $→$ The exit status of the last command executed.
# - `$$` $→$ The process ID of the current shell. For shell scripts, this is the process ID under which they are executing.
# - `$!` $→$ The process number of the last background command.
# - `$IFS`$→$ Internal Field Seperator.

# %% [markdown]
# ### Shell command separator/control characters:

# %% [markdown]
# - The ``` `` ``` is called Command Substitution and is equivalent to ``$()``, while you are using `${}`.

# %% [markdown]
# | Bash Widgets      | Meaning                                                                                                                                                                                                                                                                                                                                                                                  |
# | ----------------- | ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | `$(exprsn)`       | Example: `my_var = $(ls -1)` `ls -l $(which cp)`                                                                                                                                                                                                                                                                                                                                         |
# | `$((mth-exprsn))` | Example: ` my_var = $(( 2 + 8))` `echo $(($((5**2)) * 3))`                                                                                                                                                                                                                                                                                                                               |
# | `$1`              | First argument supplied after the program/function on execution.                                                                                                                                                                                                                                                                                                                         |
# | `$2`              | Second argument supplied after the program/function on execution. ($3 etc.)                                                                                                                                                                                                                                                                                                              |
# | `$#`              | Shows the number of arguments.                                                                                                                                                                                                                                                                                                                                                           |
# | `$?`              | Any argument (good to use in `if` statements)                                                                                                                                                                                                                                                                                                                                            |
# | `$*`              | All arguments                                                                                                                                                                                                                                                                                                                                                                            |
# | `$@`              | All arguments                                                                                                                                                                                                                                                                                                                                                                            |
# | `#`               | commented line, anything on a line after "#" will be overlooked by the script                                                                                                                                                                                                                                                                                                            |
# | `0>`              | stdin stream director (I never seen this used in any script)                                                                                                                                                                                                                                                                                                                             |
# | `1>`              | stdout stream director (standard output)                                                                                                                                                                                                                                                                                                                                                 |
# | `2>`              | stderr stream director (standard error output)                                                                                                                                                                                                                                                                                                                                           |
# | `%`               | job character, %1 = fg job 1, %2 = fg job 2, etc.                                                                                                                                                                                                                                                                                                                                        |
# | `>>`              | stream director append to a file                                                                                                                                                                                                                                                                                                                                                         |
# | `<<`              | stdin stream director. (`cat > file << EOF` ; anything ; EOF)                                                                                                                                                                                                                                                                                                                            |
# | `>`               | stream director that will start at the top of the file (in if statements `< `and `>` may be used as greater-then and lesser-then, as: `if [ "$1" >= "2" ]`) = back-slash, takes away any special meaning with a character, `$var` will not be treated as a variable. (and a new line will not be treated as a new line) Also a before a command, removes any alias on the command as: rm |
# | `>&`              | stream director to stream director, ie. `echo "a" 1>/dev/null 2>&1` this directs `2>` to the same place as `1>`                                                                                                                                                                                                                                                                          |
# | `!$`              | last commands last argument                                                                                                                                                                                                                                                                                                                                                              |
# | `!!`              | repeat last command                                                                                                                                                                                                                                                                                                                                                                      |
# | `;`               | will separate 2 commands as if they were written on separate command lines                                                                                                                                                                                                                                                                                                               |
# | `;;`              | end of a case function in a case statement. (see `case` further down)                                                                                                                                                                                                                                                                                                                    |
# | `$`               | prefix to a variable like `"$myvar"`                                                                                                                                                                                                                                                                                                                                                     |
# | `$!`              | PID of the last child process.                                                                                                                                                                                                                                                                                                                                                           |
# | `$$`              | PID of current process (PID == Process ID)                                                                                                                                                                                                                                                                                                                                               |
# | `$0`              | Shows program that owns the current process.                                                                                                                                                                                                                                                                                                                                             |
# | `$-`              | current option flags (I never ever had to use this one)                                                                                                                                                                                                                                                                                                                                  |
# | `$_`              | Last argument/Command                                                                                                                                                                                                                                                                                                                                                                    |
# | `@`               | `$@` is equivalent to `"$1"` `"$2"` etc. (all arguments)                                                                                                                                                                                                                                                                                                                                 |
# | `*`               | wild card (`\*` can substitute any number of characters)                                                                                                                                                                                                                                                                                                                                 |
# | `?`               | wild card (`? `can substitute any single character)                                                                                                                                                                                                                                                                                                                                      |
# | `{#varname}`      | returns the length of the value of the variable as a character string |
# | `*(patternlist)`  | matches zero or more occurrences of the given patterns |
# | `+(patternlist)`  | matches one or more occurrences of the given patterns |
# | `?(patternlist)`  | matches zero or one occurrence of the given patterns |
# | `@(patternlist)`  | matches exactly one of the given patterns |
# | `!(patternlist)`  | matches anything except one of the given patterns |
# | `(UNIX command)`  | command substitution: runs the command and returns standard output |

# %% [markdown]
# ### Elements of Bash:

# %% [markdown]
# - [Pipeline](https://tiswww.case.edu/php/chet/bash/bashref.html#Pipelines):
#
#   - A pipeline is a sequence of one or more commands separated by one of the control operators `|` or `|&`

# %% [markdown]
# - [Array in Bash](https://tiswww.case.edu/php/chet/bash/bashref.html#Arrays):

# %% [markdown]
# - [Grouping Commands](https://ss64.com/bash/syntax-brackets.html):

# %% [markdown]
# - [Shell Expansion](https://tiswww.case.edu/php/chet/bash/bashref.html#Shell-Expansions): There are seven kinds of expansion performed:
#   - Brace Expansion $→$ Expansion of expressions within braces.
#   - Tilde Expansion $→$ Expansion of the ~ character.
#   - Shell Parameter Expansion $→$ How Bash expands variables to their values.
#   - Command Substitution $→$ Using the output of a command as an argument.
#   - Arithmetic Expansion $→$ How to use arithmetic in shell expansions.
#   - Process Substitution $→$ A way to write and read to and from a command.
#   - Word Splitting $→$ How the results of expansion are split into separate arguments.
#   - Filename Expansion $→$ A shorthand for specifying filenames matching patterns.

# %% [markdown]
# - [All about redirections](https://catonmat.net/bash-one-liners-explained-part-three)

# %% [markdown]
# ### Flags/Options in Bash:

# %% [markdown]
# - [Bash Reference Manual](https://www.gnu.org/software/bash/manual/html_node/index.html)
# - [Taking command line arguments using flags in bash](https://dev.to/shriaas2898/taking-command-line-arguments-using-flags-in-bash-121)
# - [Different ways to implement flags in bash](https://jonalmeida.com/posts/2013/05/26/different-ways-to-implement-flags-in-bash/)
# -

# %% [markdown]
# ### Some Discovered Errors:

# %% [markdown]
# ```bash
# # Brace Expension errors !
# PATHS="$SD"/WORKSPACE_SETUP/.{git-aliases.bash,git-completion.bash,git-prompt.sh}
#
# # Error
# PATHS="$SD/WORKSPACE_SETUP.git-aliases.bash $SD/WORKSPACE_SETUP.git-completion.bash $SD/WORKSPACE_SETUP.git-prompt.sh"
#
# ```

# %% [markdown]
# ### Control Flow in Bash:

# %% [markdown]
# - **Remarks:**
#
#   - contition is written in square brackets.
#   - when use mathematical operator in conditions or elsewhere use double parenthesis.

# %% [markdown]
# ```bash
# if [ expr1 ]; then
#     statments ...
# elif [ expr2 ]; then
#     statments ...
# elif [ expr3 ]; then
#     statments ...
# else
#     statments ...
# fi
# ```

# %% [markdown]
# ### Looping in Bash:

# %% [markdown]
# - **Remarks:**

# %% [markdown]
# #### for:

# %% [markdown]
# ##### Operating on a file list contained in a variable

# %%
operate_on_files(){

    FILES="/usr/sbin/accept
    /usr/sbin/pwck
    /usr/sbin/chroot
    /usr/bin/fakefile
    /sbin/badblocks
    /sbin/ypbind"     # List of files you are curious about.
                      # Threw in a dummy file, /usr/bin/fakefile.

    echo

    for file in $FILES
    do

      if [ ! -e "$file" ] then    # Check if file exists.
        echo "$file does not exist."; echo
        continue                # On to next.
       fi

      ls -l $file | awk '{ print $8 "         file size: " $5 }'  # Print 2 fields.
      whatis `basename $file`   # File info.
      # Note that the whatis database needs to have been set up for this to work.
      # To do this, as root run /usr/bin/makewhatis.
      echo
    done  

    exit 0
}

# %% [markdown]
# ##### Find a particular string in the binaries in a specified directory.

# %%
#!/bin/bash
# findstring.sh:

directory=/usr/bin/
fstring="Free Software Foundation"  # See which files come from the FSF.

for file in $( find $directory -type f -name '*' | sort ) do
  strings -f $file | grep "$fstring" | sed -e "s%$directory%%"
  #  In the "sed" expression,
  #+ it is necessary to substitute for the normal "/" delimiter
  #+ because "/" happens to be one of the characters filtered out.
  #  Failure to do so gives an error message. (Try it.)
done  

exit $?

#  Exercise (easy):
#  ---------------
#  Convert this script to take command-line parameters
#+ for $directory and $fstring.

# %% [markdown]
# ##### Symbolic links in a directory, saved to a file

# %%
#!/bin/bash
# symlinks.sh: Lists symbolic links in a directory.

OUTFILE=symlinks.list                         # save-file

directory=${1-`pwd`}
#  Defaults to current working directory,
#+ if not otherwise specified.


echo "symbolic links in directory \"$directory\"" > "$OUTFILE"
echo "---------------------------" >> "$OUTFILE"

for file in "$( find $directory -type l )"    # -type l = symbolic links
do
  echo "$file"
done | sort >> "$OUTFILE"                     # stdout of loop
#           ^^^^^^^^^^^^^                       redirected to save file.

# echo "Output file = $OUTFILE"

exit $?

# %% [markdown]
# ##### Nested Loop

# %%
#!/bin/bash
# nested-loop.sh: Nested "for" loops.

outer=1             # Set outer loop counter.

# Beginning of outer loop.
for a in 1 2 3 4 5
do
  echo "Pass $outer in outer loop."
  echo "---------------------"
  inner=1           # Reset inner loop counter.

  # ===============================================
  # Beginning of inner loop.
  for b in 1 2 3 4 5
  do
    echo "Pass $inner in inner loop."
    let "inner+=1"  # Increment inner loop counter.
  done
  # End of inner loop.
  # ===============================================

  let "outer+=1"    # Increment outer loop counter. 
  echo              # Space between output blocks in pass of outer loop.
done               
# End of outer loop.

exit 0

# %%
# Process each file in directory_1, comparing it to directory_2
missing=0
for filename in "$1"/*; do
    fn=$(basename "$filename")
    if [ -f "$filename" ]; then
        if [ ! -f "$2/$fn" ]; then
            echo "$fn is missing from $2"
            missing=$((missing + 1))
        fi
    fi
done
echo "$missing files missing"

# %% [markdown]
# ##### Various ways of geting list of files's path

# %% [markdown]
# ```bash
# for entry in `ls $search_dir`; do
#     echo $entry
# done
#
# for entry in "$search_dir"/* "$work_dir"/*
# do
#   if [ -f "$entry" ];then
#     echo "$entry"
#   fi
# done
#
# $ pwd
# /home/victoria
#
# $ find $(pwd) -maxdepth 1 -type f -not -path '*/\.*' | sort
# /home/victoria/new
# /home/victoria/new1
# /home/victoria/new2
# /home/victoria/new3
# /home/victoria/new3.md
# /home/victoria/new.md
# /home/victoria/package.json
# /home/victoria/Untitled Document 1
# /home/victoria/Untitled Document 2
#
# $ find . -maxdepth 1 -type f -not -path '*/\.*' | sed 's/^\.\///g' | sort
# new
# new1
# new2
# new3
# new3.md
# new.md
# package.json
# Untitled Document 1
# Untitled Document 2
# ```
#
# - `.` : current folder
# - remove `-maxdepth 1` to search recursively
# - `-type f `: find files, not directories (`d`)
# - `-not -path '*/\.*'` : do not return `.hidden_files`
# - `sed 's/^\.\///g'` : remove the prepended `./` from the result list

# %% [markdown]
# #### while:

# %% [markdown]
# ##### While loop with multiple conditions

# %% [markdown]
# ```bash
# var1=unset
# previous=$var1
#
# while echo "previous-variable = $previous"
#       echo
#       previous=$var1
#       [ "$var1" != end ] # Keeps track of what $var1 was previously.
#       # Four conditions on *while*, but only the final one controls loop.
#       # The *last* exit status is the one that counts.
# do
# echo "Input variable #1 (end to exit) "
#   read var1
#   echo "variable #1 = $var1"
# done
#
# # Try to figure out how this all works.
# # It's a wee bit tricky.
#
# exit 0
# ```

# %% [markdown]
# ##### Inside its test brackets, a while loop can call a function.

# %% [markdown]
# ```bash
# t=0
#
# condition ()
# {
#   ((t++))
#
#   if [ $t -lt 5 ]
#   then
#     return 0  # true
#   else
#     return 1  # false
#   fi
# }
#
# while condition
# #     ^^^^^^^^^
# #     Function call -- four loop iterations.
# do
#   echo "Still going: t = $t"
# done
#
# # Still going: t = 1
# # Still going: t = 2
# # Still going: t = 3
# # Still going: t = 4
# ```
#
#
#
#
#
# ```bash
# number=0
# while [ "$number" -lt 10 ]; do
#     echo "Number = $number"
#     number=$((number + 1))
# done
# ```

# %% [markdown]
# ### Utilities in Bash:

# %% [markdown]
# #### find:

# %%
# man find

# %%
# List out all the items contained in the  current directory.
# find .

# %%
# List out oll files with extention .py
find *.md
# Out:
# README.md

# %%
# List out all the items contained in the  specified directory.
find dirName

# %%
# List out all the items contained in the  current and it’s subdirectoies
# find . type d

# %%
# List out all the files contained in the  current and it’s subdirectoies
# find . type f

# %%
# Return file_name.xtn file from current or whichever subdirectory it is in.
# find . type f –name index.html

# %%
# Return all the files starting with “fi” from current or it’s subdirectory. (case Sensative)
# find . type f –name fi*

# %%
# Return all the directories starting with “dirName” from current or it’s subdirectory. (case Sensative)
find . -type d –name my_bash_script
# Out:
# find: –name: unknown primary or operator
# : 1

# %%
# Return all the files starting with “bash_” from current or it’s subdirectory. (case Insensative)
find . type f –iname bash_*
# Out:
# .
# ./pure-bash-bible
# ./pure-bash-bible/manuscript
# ./pure-bash-bible/manuscript/chapter0.txt
# ./pure-bash-bible/manuscript/chapter06-variables.md
# ./pure-bash-bible/manuscript/chapter10-conditional-expression.md
# ./pure-bash-bible/manuscript/chapter08-parameter-expansion.md
# ./pure-bash-bible/manuscript/chapter15.md
# ./pure-bash-bible/manuscript/chapter05-file-path.md
# ./pure-bash-bible/manuscript/chapter14.md
# ./pure-bash-bible/manuscript/chapter11-ARITHMETIC-OPERATORS.md
# ./pure-bash-bible/manuscript/chapter18.txt
# ./pure-bash-bible/manuscript/chapter19-OTHERS.md
# ./pure-bash-bible/manuscript/Book.txt
# ./pure-bash-bible/manuscript/chapter01-string.md
# ./pure-bash-bible/manuscript/chapter07-escape-sequence.md
# ./pure-bash-bible/manuscript/chapter09-brace-expansion.md
# ./pure-bash-bible/manuscript/chapter02-array.md
# ./pure-bash-bible/manuscript/chapter13.md
# ./pure-bash-bible/manuscript/chapter17-terminal-info.md
# ./pure-bash-bible/manuscript/chapter12.md
# ./pure-bash-bible/manuscript/chapter03-loop.md
# ./pure-bash-bible/manuscript/chapter16.md
# ./pure-bash-bible/manuscript/chapter04-file-handling.md
# ./pure-bash-bible/LICENSE.md
# ./pure-bash-bible/README.md
# ./pure-bash-bible/build.sh
# ./pure-bash-bible/CONTRIBUTING.md
# ./pure-bash-bible/.git
# ./pure-bash-bible/.git/config
# ./pure-bash-bible/.git/objects
# ./pure-bash-bible/.git/objects/pack
# ./pure-bash-bible/.git/objects/pack/pack-057c0474a83a5a77a883555dc8fcd404833fe48e.idx
# ./pure-bash-bible/.git/objects/pack/pack-057c0474a83a5a77a883555dc8fcd404833fe48e.pack
# ./pure-bash-bible/.git/objects/info
# ./pure-bash-bible/.git/HEAD
# ./pure-bash-bible/.git/info
# ./pure-bash-bible/.git/info/exclude
# ./pure-bash-bible/.git/logs
# ./pure-bash-bible/.git/logs/HEAD
# ./pure-bash-bible/.git/logs/refs
# ./pure-bash-bible/.git/logs/refs/heads
# ./pure-bash-bible/.git/logs/refs/heads/master
# ./pure-bash-bible/.git/logs/refs/remotes
# ./pure-bash-bible/.git/logs/refs/remotes/origin
# ./pure-bash-bible/.git/logs/refs/remotes/origin/HEAD
# ./pure-bash-bible/.git/description
# ./pure-bash-bible/.git/hooks
# ./pure-bash-bible/.git/hooks/commit-msg.sample
# ./pure-bash-bible/.git/hooks/pre-rebase.sample
# ./pure-bash-bible/.git/hooks/pre-commit.sample
# ./pure-bash-bible/.git/hooks/applypatch-msg.sample
# ./pure-bash-bible/.git/hooks/fsmonitor-watchman.sample
# ./pure-bash-bible/.git/hooks/pre-receive.sample
# ./pure-bash-bible/.git/hooks/prepare-commit-msg.sample
# ./pure-bash-bible/.git/hooks/post-update.sample
# ./pure-bash-bible/.git/hooks/pre-applypatch.sample
# ./pure-bash-bible/.git/hooks/pre-push.sample
# ./pure-bash-bible/.git/hooks/update.sample
# ./pure-bash-bible/.git/refs
# ./pure-bash-bible/.git/refs/heads
# ./pure-bash-bible/.git/refs/heads/master
# ./pure-bash-bible/.git/refs/tags
# ./pure-bash-bible/.git/refs/remotes
# ./pure-bash-bible/.git/refs/remotes/origin
# ./pure-bash-bible/.git/refs/remotes/origin/HEAD
# ./pure-bash-bible/.git/index
# ./pure-bash-bible/.git/branches
# ./pure-bash-bible/.git/packed-refs
# ./pure-bash-bible/test.sh
# ./pure-bash-bible/.travis.yml
# ./sys_check
# ./index2.html
# ./index.html
# ./config2
# ./bash_programming.ipynb
# ./config
# ./config2.bak
# ./my_bash_script
# ./my_bash_script/bash_functions.sh
# ./my_bash_script/loop.sh
# ./my_bash_script/bash_basic.sh
# ./my_bash_script/check.sh
# ./README.md
# ./.venv
# ./.venv/bin
# ./.venv/bin/pip3.7
# ./.venv/bin/jupyter-run
# ./.venv/bin/python3
# ./.venv/bin/easy_install
# ./.venv/bin/python
# ./.venv/bin/pip3
# ./.venv/bin/ipython
# ./.venv/bin/activate.fish
# ./.venv/bin/easy_install-3.7
# ./.venv/bin/ipython3
# ./.venv/bin/pip
# ./.venv/bin/jupyter-troubleshoot
# ./.venv/bin/pygmentize
# ./.venv/bin/jupyter-migrate
# ./.venv/bin/activate
# ./.venv/bin/iptest3
# ./.venv/bin/jupyter-kernelspec
# ./.venv/bin/jupyter-kernel
# ./.venv/bin/jupyter
# ./.venv/bin/iptest
# ./.venv/bin/activate.csh
# ./.venv/include
# ./.venv/pyvenv.cfg
# ./.venv/lib
# ./.venv/lib/python3.7
# ./.venv/lib/python3.7/site-packages
# ./.venv/lib/python3.7/site-packages/debugpy-1.6.0.dist-info
# ./.venv/lib/python3.7/site-packages/debugpy-1.6.0.dist-info/RECORD
# ./.venv/lib/python3.7/site-packages/debugpy-1.6.0.dist-info/LICENSE
# ./.venv/lib/python3.7/site-packages/debugpy-1.6.0.dist-info/WHEEL
# ./.venv/lib/python3.7/site-packages/debugpy-1.6.0.dist-info/top_level.txt
# ./.venv/lib/python3.7/site-packages/debugpy-1.6.0.dist-info/INSTALLER
# ./.venv/lib/python3.7/site-packages/debugpy-1.6.0.dist-info/METADATA
# ./.venv/lib/python3.7/site-packages/appnope
# ./.venv/lib/python3.7/site-packages/appnope/_nope.py
# ./.venv/lib/python3.7/site-packages/appnope/__init__.py
# ./.venv/lib/python3.7/site-packages/appnope/__pycache__
# ./.venv/lib/python3.7/site-packages/appnope/__pycache__/_dummy.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/appnope/__pycache__/__init__.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/appnope/__pycache__/_nope.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/appnope/_dummy.py
# ./.venv/lib/python3.7/site-packages/packaging
# ./.venv/lib/python3.7/site-packages/packaging/tags.py
# ./.venv/lib/python3.7/site-packages/packaging/_musllinux.py
# ./.venv/lib/python3.7/site-packages/packaging/version.py
# ./.venv/lib/python3.7/site-packages/packaging/__init__.py
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/_structures.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/version.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/requirements.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/markers.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/_musllinux.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/tags.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/_manylinux.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/specifiers.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/utils.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/__about__.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/__init__.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/packaging/utils.py
# ./.venv/lib/python3.7/site-packages/packaging/requirements.py
# ./.venv/lib/python3.7/site-packages/packaging/_structures.py
# ./.venv/lib/python3.7/site-packages/packaging/markers.py
# ./.venv/lib/python3.7/site-packages/packaging/__about__.py
# ./.venv/lib/python3.7/site-packages/packaging/py.typed
# ./.venv/lib/python3.7/site-packages/packaging/_manylinux.py
# ./.venv/lib/python3.7/site-packages/packaging/specifiers.py
# ./.venv/lib/python3.7/site-packages/appnope-0.1.3.dist-info
# ./.venv/lib/python3.7/site-packages/appnope-0.1.3.dist-info/RECORD
# ./.venv/lib/python3.7/site-packages/appnope-0.1.3.dist-info/LICENSE
# ./.venv/lib/python3.7/site-packages/appnope-0.1.3.dist-info/WHEEL
# ./.venv/lib/python3.7/site-packages/appnope-0.1.3.dist-info/top_level.txt
# ./.venv/lib/python3.7/site-packages/appnope-0.1.3.dist-info/INSTALLER
# ./.venv/lib/python3.7/site-packages/appnope-0.1.3.dist-info/METADATA
# ./.venv/lib/python3.7/site-packages/decorator-5.1.1.dist-info
# ./.venv/lib/python3.7/site-packages/decorator-5.1.1.dist-info/RECORD
# ./.venv/lib/python3.7/site-packages/decorator-5.1.1.dist-info/WHEEL
# ./.venv/lib/python3.7/site-packages/decorator-5.1.1.dist-info/pbr.json
# ./.venv/lib/python3.7/site-packages/decorator-5.1.1.dist-info/top_level.txt
# ./.venv/lib/python3.7/site-packages/decorator-5.1.1.dist-info/LICENSE.txt
# ./.venv/lib/python3.7/site-packages/decorator-5.1.1.dist-info/INSTALLER
# ./.venv/lib/python3.7/site-packages/decorator-5.1.1.dist-info/METADATA
# ./.venv/lib/python3.7/site-packages/traitlets-5.1.1.dist-info
# ./.venv/lib/python3.7/site-packages/traitlets-5.1.1.dist-info/RECORD
# ./.venv/lib/python3.7/site-packages/traitlets-5.1.1.dist-info/WHEEL
# ./.venv/lib/python3.7/site-packages/traitlets-5.1.1.dist-info/COPYING.md
# ./.venv/lib/python3.7/site-packages/traitlets-5.1.1.dist-info/top_level.txt
# ./.venv/lib/python3.7/site-packages/traitlets-5.1.1.dist-info/INSTALLER
# ./.venv/lib/python3.7/site-packages/traitlets-5.1.1.dist-info/METADATA
# ./.venv/lib/python3.7/site-packages/wcwidth
# ./.venv/lib/python3.7/site-packages/wcwidth/version.json
# ./.venv/lib/python3.7/site-packages/wcwidth/wcwidth.py
# ./.venv/lib/python3.7/site-packages/wcwidth/table_zero.py
# ./.venv/lib/python3.7/site-packages/wcwidth/tests
# ./.venv/lib/python3.7/site-packages/wcwidth/tests/test_core.py
# ./.venv/lib/python3.7/site-packages/wcwidth/tests/__init__.py
# ./.venv/lib/python3.7/site-packages/wcwidth/tests/__pycache__
# ./.venv/lib/python3.7/site-packages/wcwidth/tests/__pycache__/test_core.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/wcwidth/tests/__pycache__/__init__.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/wcwidth/__init__.py
# ./.venv/lib/python3.7/site-packages/wcwidth/__pycache__
# ./.venv/lib/python3.7/site-packages/wcwidth/__pycache__/table_zero.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/wcwidth/__pycache__/unicode_versions.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/wcwidth/__pycache__/wcwidth.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/wcwidth/__pycache__/__init__.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/wcwidth/__pycache__/table_wide.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/wcwidth/table_wide.py
# ./.venv/lib/python3.7/site-packages/wcwidth/unicode_versions.py
# ./.venv/lib/python3.7/site-packages/ipykernel-6.12.0.dist-info
# ./.venv/lib/python3.7/site-packages/ipykernel-6.12.0.dist-info/RECORD
# ./.venv/lib/python3.7/site-packages/ipykernel-6.12.0.dist-info/WHEEL
# ./.venv/lib/python3.7/site-packages/ipykernel-6.12.0.dist-info/COPYING.md
# ./.venv/lib/python3.7/site-packages/ipykernel-6.12.0.dist-info/top_level.txt
# ./.venv/lib/python3.7/site-packages/ipykernel-6.12.0.dist-info/INSTALLER
# ./.venv/lib/python3.7/site-packages/ipykernel-6.12.0.dist-info/METADATA
# ./.venv/lib/python3.7/site-packages/jupyter_core
# ./.venv/lib/python3.7/site-packages/jupyter_core/command.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/version.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/paths.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/test_command.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/ipython_config.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/ipython_console_config.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/ipython_nbconvert_config.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/__pycache__
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/__pycache__/ipython_config.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/__pycache__/ipython_nbconvert_config.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/__pycache__/ipython_console_config.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/__pycache__/ipython_kernel_config.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/__pycache__/ipython_notebook_config.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/ipython_kernel_config.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/static
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/static/custom
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/static/custom/custom.js
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/static/custom/custom.css
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/ipython_notebook_config.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/nbextensions
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/nbextensions/myext.js
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/ipython_config.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/ipython_console_config.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/ipython_nbconvert_config.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/__pycache__
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/__pycache__/ipython_config.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/__pycache__/ipython_nbconvert_config.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/__pycache__/ipython_console_config.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/__pycache__/ipython_kernel_config.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/__pycache__/ipython_notebook_config.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/ipython_kernel_config.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/static
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/static/custom
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/static/custom/custom.js
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/static/custom/custom.css
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/ipython_notebook_config.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/__init__.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/__pycache__
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/__pycache__/mocking.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/__pycache__/test_application.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/__pycache__/test_migrate.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/__pycache__/test_command.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/__pycache__/test_paths.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/__pycache__/__init__.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/mocking.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/test_paths.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/test_application.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/test_migrate.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/__init__.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/utils
# ./.venv/lib/python3.7/site-packages/jupyter_core/utils/__init__.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/utils/__pycache__
# ./.venv/lib/python3.7/site-packages/jupyter_core/utils/__pycache__/__init__.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/__pycache__
# ./.venv/lib/python3.7/site-packages/jupyter_core/__pycache__/version.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/__pycache__/paths.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/__pycache__/migrate.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/__pycache__/application.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/__pycache__/__main__.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/__pycache__/command.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/__pycache__/troubleshoot.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/__pycache__/__init__.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/jupyter_core/application.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/troubleshoot.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/migrate.py
# ./.venv/lib/python3.7/site-packages/jupyter_core/__main__.py
# ./.venv/lib/python3.7/site-packages/tornado-6.1.dist-info
# ./.venv/lib/python3.7/site-packages/tornado-6.1.dist-info/RECORD
# ./.venv/lib/python3.7/site-packages/tornado-6.1.dist-info/LICENSE
# ./.venv/lib/python3.7/site-packages/tornado-6.1.dist-info/WHEEL
# ./.venv/lib/python3.7/site-packages/tornado-6.1.dist-info/top_level.txt
# ./.venv/lib/python3.7/site-packages/tornado-6.1.dist-info/INSTALLER
# ./.venv/lib/python3.7/site-packages/tornado-6.1.dist-info/METADATA
# ./.venv/lib/python3.7/site-packages/ptyprocess-0.7.0.dist-info
# ./.venv/lib/python3.7/site-packages/ptyprocess-0.7.0.dist-info/RECORD
# ./.venv/lib/python3.7/site-packages/ptyprocess-0.7.0.dist-info/LICENSE
# ./.venv/lib/python3.7/site-packages/ptyprocess-0.7.0.dist-info/WHEEL
# ./.venv/lib/python3.7/site-packages/ptyprocess-0.7.0.dist-info/INSTALLER
# ./.venv/lib/python3.7/site-packages/ptyprocess-0.7.0.dist-info/METADATA
# ./.venv/lib/python3.7/site-packages/backcall
# ./.venv/lib/python3.7/site-packages/backcall/__init__.py
# ./.venv/lib/python3.7/site-packages/backcall/__pycache__
# ./.venv/lib/python3.7/site-packages/backcall/__pycache__/backcall.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/backcall/__pycache__/_signatures.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/backcall/__pycache__/__init__.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/backcall/backcall.py
# ./.venv/lib/python3.7/site-packages/backcall/_signatures.py
# ./.venv/lib/python3.7/site-packages/easy_install.py
# ./.venv/lib/python3.7/site-packages/python_dateutil-2.8.2.dist-info
# ./.venv/lib/python3.7/site-packages/python_dateutil-2.8.2.dist-info/zip-safe
# ./.venv/lib/python3.7/site-packages/python_dateutil-2.8.2.dist-info/RECORD
# ./.venv/lib/python3.7/site-packages/python_dateutil-2.8.2.dist-info/LICENSE
# ./.venv/lib/python3.7/site-packages/python_dateutil-2.8.2.dist-info/WHEEL
# ./.venv/lib/python3.7/site-packages/python_dateutil-2.8.2.dist-info/top_level.txt
# ./.venv/lib/python3.7/site-packages/python_dateutil-2.8.2.dist-info/INSTALLER
# ./.venv/lib/python3.7/site-packages/python_dateutil-2.8.2.dist-info/METADATA
# ./.venv/lib/python3.7/site-packages/pygments
# ./.venv/lib/python3.7/site-packages/pygments/filters
# ./.venv/lib/python3.7/site-packages/pygments/filters/__init__.py
# ./.venv/lib/python3.7/site-packages/pygments/filters/__pycache__
# ./.venv/lib/python3.7/site-packages/pygments/filters/__pycache__/__init__.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/modeline.py
# ./.venv/lib/python3.7/site-packages/pygments/console.py
# ./.venv/lib/python3.7/site-packages/pygments/scanner.py
# ./.venv/lib/python3.7/site-packages/pygments/formatter.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers
# ./.venv/lib/python3.7/site-packages/pygments/lexers/c_like.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/ampl.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/agile.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/graphics.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/hdl.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/ecl.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/futhark.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_postgres_builtins.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/console.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/mime.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_lua_builtins.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/capnproto.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/nimrod.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/rebol.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/objective.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/sas.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/usd.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/crystal.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_sourcemod_builtins.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/web.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/verification.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/erlang.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/apdlexer.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/slash.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/boa.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/elpi.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/maxima.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/chapel.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/configs.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/clean.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/jslt.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/qvt.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/inferno.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/nix.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/parasail.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/smithy.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/graphviz.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/r.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/pawn.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/idl.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/iolang.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/amdgpu.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/dsls.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/supercollider.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/solidity.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_scilab_builtins.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_lilypond_builtins.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/lisp.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/j.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/mosel.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_vbscript_builtins.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_openedge_builtins.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/smalltalk.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/spice.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/monte.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/webmisc.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/teal.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/c_cpp.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/perl.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/robotframework.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/textfmts.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/prolog.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/rnc.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_julia_builtins.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/algebra.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/typoscript.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/automation.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/sieve.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/esoteric.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/graph.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/html.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_php_builtins.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/shell.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/scripting.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/gsql.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/gdscript.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/ambient.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/arrow.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/oberon.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_stata_builtins.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/floscript.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/resource.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__init__.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/d.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/ruby.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/other.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/pony.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/matlab.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/felix.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/tnt.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_vim_builtins.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/freefem.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/thingsdb.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/teraterm.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/parsers.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/theorem.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/compiled.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/int_fiction.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_cocoa_builtins.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/css.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_sourcemod_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/textfmts.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/varnish.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_tsql_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/scripting.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/sophia.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/compiled.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/floscript.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/ml.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/apdlexer.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/stata.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/sas.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/perl.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_cl_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/pascal.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/gdscript.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/asm.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_julia_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/robotframework.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/markup.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/fortran.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/ooc.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/forth.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/eiffel.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_stata_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/webassembly.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/dsls.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/devicetree.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/usd.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/console.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/arrow.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/idl.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/amdgpu.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/theorem.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/r.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/matlab.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/asc.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/web.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/bdd.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/nimrod.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/kuin.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/freefem.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/cddl.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/chapel.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/lisp.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/ride.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/basic.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/configs.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/modula2.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/typoscript.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/math.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/sql.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/ambient.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/qvt.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/modeling.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/urbi.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/functional.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/solidity.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/esoteric.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/resource.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/parasail.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_csound_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/zig.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/felix.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/grammar_notation.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/mime.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_cocoa_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/foxpro.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/maxima.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/graphics.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/c_cpp.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_vim_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/ruby.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/business.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/hdl.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/teraterm.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/spice.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/templates.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_scilab_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/testing.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/diff.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/promql.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/gcodelexer.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/dalvik.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/dylan.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/text.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/igor.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/bibtex.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/teal.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/erlang.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/slash.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/rdf.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/csound.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/data.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/c_like.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/apl.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/praat.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/pointless.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/scdoc.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/smithy.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/haskell.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/julia.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/other.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/supercollider.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/python.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/algebra.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_lasso_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/haxe.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/verification.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/elpi.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/ezhil.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/jslt.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/graphviz.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/actionscript.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/j.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/x10.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/iolang.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/ampl.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_php_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/inferno.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/tcl.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/rita.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/crystal.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/sgf.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/roboconf.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/snobol.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/webidl.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/factor.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_openedge_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/rebol.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_asy_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/pawn.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/rust.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/lilypond.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/special.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/thingsdb.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/go.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/automation.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/d.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/nit.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/futhark.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_postgres_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/javascript.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/savi.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/installers.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/srcinfo.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_mql_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/monte.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/clean.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_mysql_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/webmisc.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/int_fiction.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/agile.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/make.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/elm.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/shell.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/pony.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/whiley.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/sieve.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/procfile.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/php.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/fantom.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/unicon.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/yang.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/dotnet.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_vbscript_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/textedit.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/boa.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/objective.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/xorg.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/gsql.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/smv.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_mapping.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_stan_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/trafficscript.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/nix.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/smalltalk.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/archetype.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/oberon.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/graph.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_usd_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/mosel.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/meson.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/capnproto.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/ecl.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/prolog.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/parsers.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/tnt.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/__init__.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_lua_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/rnc.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/bare.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/jvm.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/ncl.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/html.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/hexdump.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/email.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_lilypond_builtins.cpython-37.pyc
# ./.venv/lib/python3.7/site-packages/pygments/lexers/ncl.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/lilypond.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/markup.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_asy_builtins.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/igor.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/ml.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/savi.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/templates.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/forth.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/css.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/asm.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/roboconf.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_lasso_builtins.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/pascal.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/csound.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/sgf.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/webassembly.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/procfile.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/functional.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/textedit.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/installers.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/business.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/tcl.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/meson.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/basic.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_stan_builtins.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/eiffel.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/scdoc.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/rdf.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/email.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/sophia.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/modula2.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/nit.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/actionscript.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/text.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/apl.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_cl_builtins.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_mql_builtins.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/srcinfo.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/archetype.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/python.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_csound_builtins.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/factor.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/dalvik.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/go.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/unicon.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_usd_builtins.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/cddl.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/dylan.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/make.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/diff.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/xorg.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/trafficscript.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/kuin.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/jvm.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/smv.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/math.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/promql.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/php.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/sql.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/x10.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_mapping.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/gcodelexer.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/praat.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/bibtex.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/whiley.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/snobol.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_mysql_builtins.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/webidl.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/rita.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/haskell.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/testing.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/fortran.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/modeling.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/varnish.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/elm.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/asc.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/javascript.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/ooc.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/bdd.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/julia.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/hexdump.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/foxpro.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/stata.py
# ./.venv/lib/python3.7/site-packages/pygments/lexers/zig.py
# ...
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/utils/dateparse.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/utils/dateformat.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/utils/cache.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/utils/regex_helper.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/utils/jslex.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/syndication
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/syndication/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/syndication/views.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/messages
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/messages/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/messages/constants.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/messages/middleware.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/messages/api.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/messages/utils.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/messages/storage
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/messages/storage/base.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/messages/storage/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/messages/storage/fallback.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/messages/storage/cookie.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/messages/storage/session.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/messages/context_processors.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/messages/views.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/validators.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/decorators.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/base_user.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/checks.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/urls.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/backends.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/forms.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/mixins.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/management
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/management/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/management/commands
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/management/commands/createsuperuser.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/management/commands/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/management/commands/changepassword.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/admin.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/middleware.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/tokens.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/apps.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/models.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/signals.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/context_processors.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/handlers
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/handlers/modwsgi.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/handlers/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/password_validation.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/hashers.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/views.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/templatetags
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/templatetags/base.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/templatetags/admin_static.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/templatetags/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/templatetags/admin_urls.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/templatetags/admin_modify.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/templatetags/log.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/templatetags/admin_list.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/decorators.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/options.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/checks.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/forms.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/helpers.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/utils.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/apps.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/actions.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/filters.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/models.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/widgets.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/sites.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/tests.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/views
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/views/decorators.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/views/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/views/autocomplete.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/views/main.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/templatetags
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/templatetags/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/templatetags/staticfiles.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/storage.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/checks.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/urls.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/management
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/management/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/management/commands
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/management/commands/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/management/commands/collectstatic.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/management/commands/findstatic.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/management/commands/runserver.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/handlers.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/utils.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/apps.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/finders.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/testing.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/views.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/flatpages
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/flatpages/templatetags
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/flatpages/templatetags/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/flatpages/templatetags/flatpages.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/flatpages/sitemaps.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/flatpages/urls.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/flatpages/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/flatpages/forms.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/flatpages/middleware.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/flatpages/models.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/flatpages/views.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/sites
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/sites/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/sites/managers.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/sites/shortcuts.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/sites/middleware.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/sites/apps.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/sites/models.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/sites/requests.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/sites/management.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/validators.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/operations.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/aggregates
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/aggregates/statistics.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/aggregates/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/aggregates/mixins.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/aggregates/general.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/lookups.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/indexes.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/signals.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/functions.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/fields
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/fields/jsonb.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/fields/__init__.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/fields/mixins.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/fields/hstore.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/fields/citext.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/fields/ranges.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/fields/array.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/search.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/constraints.pyi
# ./.venv/lib/python3.7/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/redirects

# %%
# Return all files with extentions “.py”
find . type f –iname *.py

# %%
# Return all files modified in last five minutes.
find . type f –mmin -5
# Out:
# find: -5: unknown primary or operator
# : 1

# %%
# Return all files modified in more than 1 and less than  five minutes.
find . type f +1 –mmin -5
# Out:
# find: -5: unknown primary or operator
# : 1

# %%
# Return all files modified  (mmin; m time; a min; a time; cmin; ctime)
find . type f –mtime +5

# %% [markdown]
# #### grep:

# %%
grep "Jane Williams" ./data/names.txt
# Out:
# : 1

# %%
grep "John Williams" ./data/names.txt
# Out:
# John Williams
# John Williamson

# %%
grep -w "John Williams" ./data/names.txt
# Out:
# John Williams

# %%
grep -wi "John Williams" ./data/names.txt
# Out:
# john williams
# John Williams

# %%
grep -win "John Williams" ./data/names.txt
# Out:
# 51:john williams
# 431:John Williams

# %%
grep -win -B 4 "John Williams" ./data/names.txt
# Out:
# 47-119-555-3358
# 48-508 Pine St., Valyria MD 28445
# 49-mariajones@bogusemail.com
# 50-
# 51:john williams
# --
# 427-218-555-5260
# 428-502 Maple St., Gotham OR 44147
# 429-lauraarnold@bogusemail.com
# 430-
# 431:John Williams

# %%
grep -win -A 4 "John Williams" ./data/names.txt
# Out:
# 51:john williams
# 52-304-555-4321
# 53-607 Martin Hollow, Chucktown WV 25311
# 54-johnw@johnscompany.com
# 55-
# --
# 431:John Williams
# 432-515-555-4529
# 433-606 Pearl St., Eerie MI 10261
# 434-johnwilliams@bogusemail.com
# 435-

# %%
grep -win -C 2 "John Williams" ./data/names.txt
# Out:
# 49-mariajones@bogusemail.com
# 50-
# 51:john williams
# 52-304-555-4321
# 53-607 Martin Hollow, Chucktown WV 25311
# --
# 429-lauraarnold@bogusemail.com
# 430-
# 431:John Williams
# 432-515-555-4529
# 433-606 Pearl St., Eerie MI 10261

# %%
grep -win "John Williams" ./*
# Out:
# ./bash_programming.ipynb:929:    "grep \"John Williams\" ./data/names.txt"
# ./bash_programming.ipynb:947:    "grep -w \"John Williams\" ./data/names.txt"
# ./bash_programming.ipynb:966:    "grep -wi \"John Williams\" ./data/names.txt"
# ./bash_programming.ipynb:985:    "grep -win \"John Williams\" ./data/names.txt"
# ./bash_programming.ipynb:1013:    "grep -win -B 4 \"John Williams\" ./data/names.txt"
# ./bash_programming.ipynb:1041:    "grep -win -A 4 \"John Williams\" ./data/names.txt"
# ./bash_programming.ipynb:1051:    "grep -win -C 2 \"John Williams\" names.txt"
# ./bash_programming.ipynb:1061:    "grep -win \"John Williams\" ./*"
# ./bash_programming.ipynb:1071:    "grep -win \"John Williams\" ./*.txt"
# ./bash_programming.ipynb:1081:    "grep -winr \"John Williams\" ."
# ./bash_programming.ipynb:1091:    "grep -wirl \"John Williams\" ."
# ./bash_programming.ipynb:1101:    "grep -wirc \"John Williams\" ."
# grep: ./data: Is a directory
# grep: ./my_bash_script: Is a directory
# grep: ./pure-bash-bible: Is a directory
# : 2

# %%
grep -win "John Williams" ./*.txt
# Out:
# grep: ./*.txt: No such file or directory
# : 2

# %%
grep -winr "John Williams" .
# Out:
# ./bash_programming.ipynb:929:    "grep \"John Williams\" ./data/names.txt"
# ./bash_programming.ipynb:947:    "grep -w \"John Williams\" ./data/names.txt"
# ./bash_programming.ipynb:966:    "grep -wi \"John Williams\" ./data/names.txt"
# ./bash_programming.ipynb:985:    "grep -win \"John Williams\" ./data/names.txt"
# ./bash_programming.ipynb:1013:    "grep -win -B 4 \"John Williams\" ./data/names.txt"
# ./bash_programming.ipynb:1041:    "grep -win -A 4 \"John Williams\" ./data/names.txt"
# ./bash_programming.ipynb:1051:    "grep -win -C 2 \"John Williams\" names.txt"
# ./bash_programming.ipynb:1061:    "grep -win \"John Williams\" ./*"
# ./bash_programming.ipynb:1071:    "grep -win \"John Williams\" ./*.txt"
# ./bash_programming.ipynb:1081:    "grep -winr \"John Williams\" ."
# ./bash_programming.ipynb:1091:    "grep -wirl \"John Williams\" ."
# ./bash_programming.ipynb:1101:    "grep -wirc \"John Williams\" ."
# ./.ipynb_checkpoints/bash_programming-checkpoint.ipynb:913:    "grep \"John Williams\" names.txt"
# ./.ipynb_checkpoints/bash_programming-checkpoint.ipynb:923:    "grep -w \"John Williams\" names.txt"
# ./.ipynb_checkpoints/bash_programming-checkpoint.ipynb:933:    "grep -wi \"John Williams\" names.txt"
# ./.ipynb_checkpoints/bash_programming-checkpoint.ipynb:943:    "grep -win \"John Williams\" names.txt"
# ./.ipynb_checkpoints/bash_programming-checkpoint.ipynb:953:    "grep -win -B 4 \"John Williams\" names.txt"
# ./.ipynb_checkpoints/bash_programming-checkpoint.ipynb:963:    "grep -win -A 4 \"John Williams\" names.txt"
# ./.ipynb_checkpoints/bash_programming-checkpoint.ipynb:973:    "grep -win -C 2 \"John Williams\" names.txt"
# ./.ipynb_checkpoints/bash_programming-checkpoint.ipynb:983:    "grep -win \"John Williams\" ./*"
# ./.ipynb_checkpoints/bash_programming-checkpoint.ipynb:993:    "grep -win \"John Williams\" ./*.txt"
# ./.ipynb_checkpoints/bash_programming-checkpoint.ipynb:1003:    "grep -winr \"John Williams\" ."
# ./.ipynb_checkpoints/bash_programming-checkpoint.ipynb:1013:    "grep -wirl \"John Williams\" ."
# ./.ipynb_checkpoints/bash_programming-checkpoint.ipynb:1023:    "grep -wirc \"John Williams\" ."
# ./data/names.txt:51:john williams
# ./data/names.txt:431:John Williams
# ./data/Personel/phone_numbers.txt:5:John Williams
# ./data/Personel/emails.txt:5:John Williams
# ./data/grep-commands.txt:2:grep "John Williams" names.txt
# ./data/grep-commands.txt:4:grep -w "John Williams" names.txt
# ./data/grep-commands.txt:5:grep -wi "John Williams" names.txt
# ./data/grep-commands.txt:6:grep -win "John Williams" names.txt
# ./data/grep-commands.txt:8:grep -win -B 4 "John Williams" names.txt
# ./data/grep-commands.txt:9:grep -win -A 4 "John Williams" names.txt
# ./data/grep-commands.txt:10:grep -win -C 2 "John Williams" names.txt
# ./data/grep-commands.txt:12:grep -win "John Williams" ./*
# ./data/grep-commands.txt:13:grep -win "John Williams" ./*.txt
# ./data/grep-commands.txt:14:grep -winr "John Williams" .
# ./data/grep-commands.txt:15:grep -wirl "John Williams" .
# ./data/grep-commands.txt:16:grep -wirc "John Williams" .
# ./data/memo.txt:4:In our meeting today, John Williams had mentioned that the work could be completed by the end of the month.

# %%
grep -wirl "John Williams" .
# Out:
# ./bash_programming.ipynb
# ./.ipynb_checkpoints/bash_programming-checkpoint.ipynb
# ./data/names.txt
# ./data/Personel/phone_numbers.txt
# ./data/Personel/emails.txt
# ./data/grep-commands.txt
# ./data/memo.txt

# %%
grep -wirc "John Williams" .
# Out:
# ./pure-bash-bible/manuscript/chapter0.txt:0
# ./pure-bash-bible/manuscript/chapter06-variables.md:0
# ./pure-bash-bible/manuscript/chapter10-conditional-expression.md:0
# ./pure-bash-bible/manuscript/chapter08-parameter-expansion.md:0
# ./pure-bash-bible/manuscript/chapter15.md:0
# ./pure-bash-bible/manuscript/chapter05-file-path.md:0
# ./pure-bash-bible/manuscript/chapter14.md:0
# ./pure-bash-bible/manuscript/chapter11-ARITHMETIC-OPERATORS.md:0
# ./pure-bash-bible/manuscript/chapter18.txt:0
# ./pure-bash-bible/manuscript/chapter19-OTHERS.md:0
# ./pure-bash-bible/manuscript/Book.txt:0
# ./pure-bash-bible/manuscript/chapter01-string.md:0
# ./pure-bash-bible/manuscript/chapter07-escape-sequence.md:0
# ./pure-bash-bible/manuscript/chapter09-brace-expansion.md:0
# ./pure-bash-bible/manuscript/chapter02-array.md:0
# ./pure-bash-bible/manuscript/chapter13.md:0
# ./pure-bash-bible/manuscript/chapter17-terminal-info.md:0
# ./pure-bash-bible/manuscript/chapter12.md:0
# ./pure-bash-bible/manuscript/chapter03-loop.md:0
# ./pure-bash-bible/manuscript/chapter16.md:0
# ./pure-bash-bible/manuscript/chapter04-file-handling.md:0
# ./pure-bash-bible/LICENSE.md:0
# ./pure-bash-bible/README.md:0
# ./pure-bash-bible/build.sh:0
# ./pure-bash-bible/CONTRIBUTING.md:0
# ./pure-bash-bible/.git/config:0
# ./pure-bash-bible/.git/objects/pack/pack-057c0474a83a5a77a883555dc8fcd404833fe48e.idx:0
# ./pure-bash-bible/.git/objects/pack/pack-057c0474a83a5a77a883555dc8fcd404833fe48e.pack:0
# ./pure-bash-bible/.git/HEAD:0
# ./pure-bash-bible/.git/info/exclude:0
# ./pure-bash-bible/.git/logs/HEAD:0
# ./pure-bash-bible/.git/logs/refs/heads/master:0
# ./pure-bash-bible/.git/logs/refs/remotes/origin/HEAD:0
# ./pure-bash-bible/.git/description:0
# ./pure-bash-bible/.git/hooks/commit-msg.sample:0
# ./pure-bash-bible/.git/hooks/pre-rebase.sample:0
# ./pure-bash-bible/.git/hooks/pre-commit.sample:0
# ./pure-bash-bible/.git/hooks/applypatch-msg.sample:0
# ./pure-bash-bible/.git/hooks/fsmonitor-watchman.sample:0
# ./pure-bash-bible/.git/hooks/pre-receive.sample:0
# ./pure-bash-bible/.git/hooks/prepare-commit-msg.sample:0
# ./pure-bash-bible/.git/hooks/post-update.sample:0
# ./pure-bash-bible/.git/hooks/pre-applypatch.sample:0
# ./pure-bash-bible/.git/hooks/pre-push.sample:0
# ./pure-bash-bible/.git/hooks/update.sample:0
# ./pure-bash-bible/.git/refs/heads/master:0
# ./pure-bash-bible/.git/refs/remotes/origin/HEAD:0
# ./pure-bash-bible/.git/index:0
# ./pure-bash-bible/.git/packed-refs:0
# ./pure-bash-bible/test.sh:0
# ./pure-bash-bible/.travis.yml:0
# ./sys_check:0
# ./index2.html:0
# ./index.html:0
# ./config2:0
# ./bash_programming.ipynb:12
# ./config:0
# ./config2.bak:0
# ./my_bash_script/bash_functions.sh:0
# ./my_bash_script/loop.sh:0
# ./my_bash_script/bash_basic.sh:0
# ./my_bash_script/check.sh:0
# ./README.md:0
# ./.venv/bin/pip3.7:0
# ./.venv/bin/jupyter-run:0
# ./.venv/bin/easy_install:0
# ./.venv/bin/pip3:0
# ./.venv/bin/ipython:0
# ./.venv/bin/activate.fish:0
# ./.venv/bin/easy_install-3.7:0
# ./.venv/bin/ipython3:0
# ./.venv/bin/pip:0
# ./.venv/bin/jupyter-troubleshoot:0
# ./.venv/bin/pygmentize:0
# ./.venv/bin/jupyter-migrate:0
# ./.venv/bin/activate:0
# ./.venv/bin/iptest3:0
# ./.venv/bin/jupyter-kernelspec:0
# ./.venv/bin/jupyter-kernel:0
# ./.venv/bin/jupyter:0
# ./.venv/bin/iptest:0
# ./.venv/bin/activate.csh:0
# ./.venv/pyvenv.cfg:0
# ./.venv/lib/python3.7/site-packages/debugpy-1.6.0.dist-info/RECORD:0
# ./.venv/lib/python3.7/site-packages/debugpy-1.6.0.dist-info/LICENSE:0
# ./.venv/lib/python3.7/site-packages/debugpy-1.6.0.dist-info/WHEEL:0
# ./.venv/lib/python3.7/site-packages/debugpy-1.6.0.dist-info/top_level.txt:0
# ./.venv/lib/python3.7/site-packages/debugpy-1.6.0.dist-info/INSTALLER:0
# ./.venv/lib/python3.7/site-packages/debugpy-1.6.0.dist-info/METADATA:0
# ./.venv/lib/python3.7/site-packages/appnope/_nope.py:0
# ./.venv/lib/python3.7/site-packages/appnope/__init__.py:0
# ./.venv/lib/python3.7/site-packages/appnope/__pycache__/_dummy.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/appnope/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/appnope/__pycache__/_nope.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/appnope/_dummy.py:0
# ./.venv/lib/python3.7/site-packages/packaging/tags.py:0
# ./.venv/lib/python3.7/site-packages/packaging/_musllinux.py:0
# ./.venv/lib/python3.7/site-packages/packaging/version.py:0
# ./.venv/lib/python3.7/site-packages/packaging/__init__.py:0
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/_structures.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/version.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/requirements.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/markers.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/_musllinux.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/tags.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/_manylinux.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/specifiers.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/utils.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/__about__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/packaging/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/packaging/utils.py:0
# ./.venv/lib/python3.7/site-packages/packaging/requirements.py:0
# ./.venv/lib/python3.7/site-packages/packaging/_structures.py:0
# ./.venv/lib/python3.7/site-packages/packaging/markers.py:0
# ./.venv/lib/python3.7/site-packages/packaging/__about__.py:0
# ./.venv/lib/python3.7/site-packages/packaging/py.typed:0
# ./.venv/lib/python3.7/site-packages/packaging/_manylinux.py:0
# ./.venv/lib/python3.7/site-packages/packaging/specifiers.py:0
# ./.venv/lib/python3.7/site-packages/appnope-0.1.3.dist-info/RECORD:0
# ./.venv/lib/python3.7/site-packages/appnope-0.1.3.dist-info/LICENSE:0
# ./.venv/lib/python3.7/site-packages/appnope-0.1.3.dist-info/WHEEL:0
# ./.venv/lib/python3.7/site-packages/appnope-0.1.3.dist-info/top_level.txt:0
# ./.venv/lib/python3.7/site-packages/appnope-0.1.3.dist-info/INSTALLER:0
# ./.venv/lib/python3.7/site-packages/appnope-0.1.3.dist-info/METADATA:0
# ./.venv/lib/python3.7/site-packages/decorator-5.1.1.dist-info/RECORD:0
# ./.venv/lib/python3.7/site-packages/decorator-5.1.1.dist-info/WHEEL:0
# ./.venv/lib/python3.7/site-packages/decorator-5.1.1.dist-info/pbr.json:0
# ./.venv/lib/python3.7/site-packages/decorator-5.1.1.dist-info/top_level.txt:0
# ./.venv/lib/python3.7/site-packages/decorator-5.1.1.dist-info/LICENSE.txt:0
# ./.venv/lib/python3.7/site-packages/decorator-5.1.1.dist-info/INSTALLER:0
# ./.venv/lib/python3.7/site-packages/decorator-5.1.1.dist-info/METADATA:0
# ./.venv/lib/python3.7/site-packages/traitlets-5.1.1.dist-info/RECORD:0
# ./.venv/lib/python3.7/site-packages/traitlets-5.1.1.dist-info/WHEEL:0
# ./.venv/lib/python3.7/site-packages/traitlets-5.1.1.dist-info/COPYING.md:0
# ./.venv/lib/python3.7/site-packages/traitlets-5.1.1.dist-info/top_level.txt:0
# ./.venv/lib/python3.7/site-packages/traitlets-5.1.1.dist-info/INSTALLER:0
# ./.venv/lib/python3.7/site-packages/traitlets-5.1.1.dist-info/METADATA:0
# ./.venv/lib/python3.7/site-packages/wcwidth/version.json:0
# ./.venv/lib/python3.7/site-packages/wcwidth/wcwidth.py:0
# ./.venv/lib/python3.7/site-packages/wcwidth/table_zero.py:0
# ./.venv/lib/python3.7/site-packages/wcwidth/tests/test_core.py:0
# ./.venv/lib/python3.7/site-packages/wcwidth/tests/__init__.py:0
# ./.venv/lib/python3.7/site-packages/wcwidth/tests/__pycache__/test_core.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/wcwidth/tests/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/wcwidth/__init__.py:0
# ./.venv/lib/python3.7/site-packages/wcwidth/__pycache__/table_zero.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/wcwidth/__pycache__/unicode_versions.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/wcwidth/__pycache__/wcwidth.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/wcwidth/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/wcwidth/__pycache__/table_wide.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/wcwidth/table_wide.py:0
# ./.venv/lib/python3.7/site-packages/wcwidth/unicode_versions.py:0
# ./.venv/lib/python3.7/site-packages/ipykernel-6.12.0.dist-info/RECORD:0
# ./.venv/lib/python3.7/site-packages/ipykernel-6.12.0.dist-info/WHEEL:0
# ./.venv/lib/python3.7/site-packages/ipykernel-6.12.0.dist-info/COPYING.md:0
# ./.venv/lib/python3.7/site-packages/ipykernel-6.12.0.dist-info/top_level.txt:0
# ./.venv/lib/python3.7/site-packages/ipykernel-6.12.0.dist-info/INSTALLER:0
# ./.venv/lib/python3.7/site-packages/ipykernel-6.12.0.dist-info/METADATA:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/command.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/version.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/paths.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/test_command.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/ipython_config.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/ipython_console_config.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/ipython_nbconvert_config.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/__pycache__/ipython_config.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/__pycache__/ipython_nbconvert_config.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/__pycache__/ipython_console_config.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/__pycache__/ipython_kernel_config.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/__pycache__/ipython_notebook_config.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/ipython_kernel_config.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/static/custom/custom.js:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/static/custom/custom.css:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/profile_default/ipython_notebook_config.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython/nbextensions/myext.js:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/ipython_config.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/ipython_console_config.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/ipython_nbconvert_config.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/__pycache__/ipython_config.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/__pycache__/ipython_nbconvert_config.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/__pycache__/ipython_console_config.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/__pycache__/ipython_kernel_config.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/__pycache__/ipython_notebook_config.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/ipython_kernel_config.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/static/custom/custom.js:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/static/custom/custom.css:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/dotipython_empty/profile_default/ipython_notebook_config.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/__init__.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/__pycache__/mocking.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/__pycache__/test_application.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/__pycache__/test_migrate.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/__pycache__/test_command.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/__pycache__/test_paths.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/mocking.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/test_paths.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/test_application.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/tests/test_migrate.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/__init__.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/utils/__init__.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/utils/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/__pycache__/version.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/__pycache__/paths.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/__pycache__/migrate.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/__pycache__/application.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/__pycache__/__main__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/__pycache__/command.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/__pycache__/troubleshoot.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/application.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/troubleshoot.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/migrate.py:0
# ./.venv/lib/python3.7/site-packages/jupyter_core/__main__.py:0
# ./.venv/lib/python3.7/site-packages/tornado-6.1.dist-info/RECORD:0
# ./.venv/lib/python3.7/site-packages/tornado-6.1.dist-info/LICENSE:0
# ./.venv/lib/python3.7/site-packages/tornado-6.1.dist-info/WHEEL:0
# ./.venv/lib/python3.7/site-packages/tornado-6.1.dist-info/top_level.txt:0
# ./.venv/lib/python3.7/site-packages/tornado-6.1.dist-info/INSTALLER:0
# ./.venv/lib/python3.7/site-packages/tornado-6.1.dist-info/METADATA:0
# ./.venv/lib/python3.7/site-packages/ptyprocess-0.7.0.dist-info/RECORD:0
# ./.venv/lib/python3.7/site-packages/ptyprocess-0.7.0.dist-info/LICENSE:0
# ./.venv/lib/python3.7/site-packages/ptyprocess-0.7.0.dist-info/WHEEL:0
# ./.venv/lib/python3.7/site-packages/ptyprocess-0.7.0.dist-info/INSTALLER:0
# ./.venv/lib/python3.7/site-packages/ptyprocess-0.7.0.dist-info/METADATA:0
# ./.venv/lib/python3.7/site-packages/backcall/__init__.py:0
# ./.venv/lib/python3.7/site-packages/backcall/__pycache__/backcall.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/backcall/__pycache__/_signatures.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/backcall/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/backcall/backcall.py:0
# ./.venv/lib/python3.7/site-packages/backcall/_signatures.py:0
# ./.venv/lib/python3.7/site-packages/easy_install.py:0
# ./.venv/lib/python3.7/site-packages/python_dateutil-2.8.2.dist-info/zip-safe:0
# ./.venv/lib/python3.7/site-packages/python_dateutil-2.8.2.dist-info/RECORD:0
# ./.venv/lib/python3.7/site-packages/python_dateutil-2.8.2.dist-info/LICENSE:0
# ./.venv/lib/python3.7/site-packages/python_dateutil-2.8.2.dist-info/WHEEL:0
# ./.venv/lib/python3.7/site-packages/python_dateutil-2.8.2.dist-info/top_level.txt:0
# ./.venv/lib/python3.7/site-packages/python_dateutil-2.8.2.dist-info/INSTALLER:0
# ./.venv/lib/python3.7/site-packages/python_dateutil-2.8.2.dist-info/METADATA:0
# ./.venv/lib/python3.7/site-packages/pygments/filters/__init__.py:0
# ./.venv/lib/python3.7/site-packages/pygments/filters/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/modeline.py:0
# ./.venv/lib/python3.7/site-packages/pygments/console.py:0
# ./.venv/lib/python3.7/site-packages/pygments/scanner.py:0
# ./.venv/lib/python3.7/site-packages/pygments/formatter.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/c_like.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/ampl.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/agile.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/graphics.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/hdl.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/ecl.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/futhark.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_postgres_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/console.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/mime.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_lua_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/capnproto.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/nimrod.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/rebol.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/objective.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/sas.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/usd.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/crystal.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_sourcemod_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/web.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/verification.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/erlang.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/apdlexer.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/slash.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/boa.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/elpi.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/maxima.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/chapel.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/configs.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/clean.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/jslt.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/qvt.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/inferno.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/nix.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/parasail.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/smithy.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/graphviz.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/r.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/pawn.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/idl.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/iolang.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/amdgpu.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/dsls.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/supercollider.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/solidity.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_scilab_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_lilypond_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/lisp.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/j.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/mosel.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_vbscript_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_openedge_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/smalltalk.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/spice.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/monte.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/webmisc.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/teal.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/c_cpp.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/perl.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/robotframework.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/textfmts.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/prolog.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/rnc.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_julia_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/algebra.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/typoscript.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/automation.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/sieve.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/esoteric.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/graph.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/html.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_php_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/shell.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/scripting.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/gsql.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/gdscript.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/ambient.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/arrow.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/oberon.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_stata_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/floscript.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/resource.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__init__.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/d.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/ruby.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/other.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/pony.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/matlab.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/felix.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/tnt.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_vim_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/freefem.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/thingsdb.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/teraterm.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/parsers.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/theorem.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/compiled.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/int_fiction.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_cocoa_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/css.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_sourcemod_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/textfmts.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/varnish.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_tsql_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/scripting.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/sophia.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/compiled.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/floscript.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/ml.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/apdlexer.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/stata.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/sas.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/perl.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_cl_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/pascal.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/gdscript.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/asm.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_julia_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/robotframework.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/markup.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/fortran.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/ooc.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/forth.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/eiffel.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_stata_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/webassembly.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/dsls.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/devicetree.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/usd.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/console.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/arrow.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/idl.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/amdgpu.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/theorem.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/r.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/matlab.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/asc.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/web.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/bdd.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/nimrod.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/kuin.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/freefem.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/cddl.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/chapel.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/lisp.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/ride.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/basic.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/configs.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/modula2.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/typoscript.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/math.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/sql.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/ambient.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/qvt.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/modeling.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/urbi.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/functional.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/solidity.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/esoteric.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/resource.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/parasail.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_csound_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/zig.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/felix.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/grammar_notation.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/mime.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_cocoa_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/foxpro.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/maxima.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/graphics.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/c_cpp.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_vim_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/ruby.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/business.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/hdl.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/teraterm.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/spice.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/templates.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_scilab_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/testing.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/diff.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/promql.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/gcodelexer.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/dalvik.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/dylan.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/text.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/igor.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/bibtex.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/teal.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/erlang.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/slash.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/rdf.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/csound.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/data.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/c_like.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/apl.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/praat.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/pointless.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/scdoc.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/smithy.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/haskell.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/julia.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/other.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/supercollider.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/python.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/algebra.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_lasso_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/haxe.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/verification.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/elpi.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/ezhil.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/jslt.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/graphviz.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/actionscript.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/j.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/x10.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/iolang.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/ampl.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_php_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/inferno.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/tcl.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/rita.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/crystal.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/sgf.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/roboconf.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/snobol.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/webidl.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/factor.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_openedge_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/rebol.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_asy_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/pawn.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/rust.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/lilypond.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/special.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/thingsdb.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/go.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/automation.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/d.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/nit.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/futhark.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_postgres_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/javascript.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/savi.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/installers.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/srcinfo.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_mql_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/monte.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/clean.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_mysql_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/webmisc.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/int_fiction.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/agile.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/make.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/elm.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/shell.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/pony.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/whiley.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/sieve.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/procfile.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/php.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/fantom.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/unicon.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/yang.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/dotnet.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_vbscript_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/textedit.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/boa.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/objective.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/xorg.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/gsql.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/smv.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_mapping.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_stan_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/trafficscript.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/nix.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/smalltalk.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/archetype.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/oberon.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/graph.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_usd_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/mosel.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/meson.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/capnproto.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/ecl.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/prolog.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/parsers.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/tnt.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_lua_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/rnc.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/bare.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/jvm.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/ncl.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/html.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/hexdump.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/email.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/__pycache__/_lilypond_builtins.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/ncl.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/lilypond.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/markup.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_asy_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/igor.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/ml.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/savi.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/templates.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/forth.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/css.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/asm.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/roboconf.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_lasso_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/pascal.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/csound.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/sgf.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/webassembly.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/procfile.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/functional.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/textedit.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/installers.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/business.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/tcl.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/meson.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/basic.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_stan_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/eiffel.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/scdoc.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/rdf.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/email.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/sophia.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/modula2.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/nit.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/actionscript.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/text.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/apl.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_cl_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_mql_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/srcinfo.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/archetype.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/python.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_csound_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/factor.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/dalvik.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/go.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/unicon.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_usd_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/cddl.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/dylan.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/make.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/diff.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/xorg.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/trafficscript.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/kuin.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/jvm.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/smv.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/math.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/promql.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/php.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/sql.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/x10.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_mapping.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/gcodelexer.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/praat.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/bibtex.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/whiley.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/snobol.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_mysql_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/webidl.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/rita.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/haskell.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/testing.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/fortran.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/modeling.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/varnish.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/elm.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/asc.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/javascript.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/ooc.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/bdd.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/julia.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/hexdump.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/foxpro.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/stata.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/zig.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/grammar_notation.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/bare.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/dotnet.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/fantom.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/special.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/yang.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/ezhil.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/ride.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/devicetree.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/urbi.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/haxe.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/data.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/pointless.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/_tsql_builtins.py:0
# ./.venv/lib/python3.7/site-packages/pygments/lexers/rust.py:0
# ./.venv/lib/python3.7/site-packages/pygments/token.py:0
# ./.venv/lib/python3.7/site-packages/pygments/style.py:0
# ./.venv/lib/python3.7/site-packages/pygments/util.py:0
# ./.venv/lib/python3.7/site-packages/pygments/sphinxext.py:0
# ./.venv/lib/python3.7/site-packages/pygments/cmdline.py:0
# ./.venv/lib/python3.7/site-packages/pygments/__init__.py:0
# ./.venv/lib/python3.7/site-packages/pygments/formatters/terminal.py:0
# ./.venv/lib/python3.7/site-packages/pygments/formatters/html.py:0
# ./.venv/lib/python3.7/site-packages/pygments/formatters/irc.py:0
# ./.venv/lib/python3.7/site-packages/pygments/formatters/__init__.py:0
# ./.venv/lib/python3.7/site-packages/pygments/formatters/other.py:0
# ./.venv/lib/python3.7/site-packages/pygments/formatters/__pycache__/groff.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/formatters/__pycache__/img.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/formatters/__pycache__/svg.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/formatters/__pycache__/rtf.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/formatters/__pycache__/other.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pygments/formatters/__pycache__/irc.cpython-37.pyc:0
# ...
# ./.venv/lib/python3.7/site-packages/setuptools/command/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/setuptools/command/__pycache__/install_egg_info.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/setuptools/command/__pycache__/install_scripts.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/setuptools/command/sdist.py:0
# ./.venv/lib/python3.7/site-packages/setuptools/command/test.py:0
# ./.venv/lib/python3.7/site-packages/setuptools/command/saveopts.py:0
# ./.venv/lib/python3.7/site-packages/setuptools/command/bdist_rpm.py:0
# ./.venv/lib/python3.7/site-packages/setuptools/command/build_clib.py:0
# ./.venv/lib/python3.7/site-packages/setuptools/command/egg_info.py:0
# ./.venv/lib/python3.7/site-packages/setuptools/command/install.py:0
# ./.venv/lib/python3.7/site-packages/setuptools/command/develop.py:0
# ./.venv/lib/python3.7/site-packages/setuptools/command/rotate.py:0
# ./.venv/lib/python3.7/site-packages/setuptools/command/install_egg_info.py:0
# ./.venv/lib/python3.7/site-packages/setuptools/command/setopt.py:0
# ./.venv/lib/python3.7/site-packages/setuptools/site-patch.py:0
# ./.venv/lib/python3.7/site-packages/setuptools/msvc.py:0
# ./.venv/lib/python3.7/site-packages/setuptools/cli-32.exe:0
# ./.venv/lib/python3.7/site-packages/setuptools/extern/__init__.py:0
# ./.venv/lib/python3.7/site-packages/setuptools/extern/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/setuptools/gui-32.exe:0
# ./.venv/lib/python3.7/site-packages/setuptools/gui.exe:0
# ./.venv/lib/python3.7/site-packages/setuptools/dist.py:0
# ./.venv/lib/python3.7/site-packages/setuptools/lib2to3_ex.py:0
# ./.venv/lib/python3.7/site-packages/setuptools/glibc.py:0
# ./.venv/lib/python3.7/site-packages/setuptools/py33compat.py:0
# ./.venv/lib/python3.7/site-packages/setuptools/wheel.py:0
# ./.venv/lib/python3.7/site-packages/setuptools/namespaces.py:0
# ./.venv/lib/python3.7/site-packages/setuptools/script (dev).tmpl:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/packaging/version.py:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/packaging/__init__.py:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/packaging/__pycache__/_structures.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/packaging/__pycache__/version.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/packaging/__pycache__/requirements.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/packaging/__pycache__/markers.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/packaging/__pycache__/_compat.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/packaging/__pycache__/specifiers.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/packaging/__pycache__/utils.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/packaging/__pycache__/__about__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/packaging/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/packaging/utils.py:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/packaging/requirements.py:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/packaging/_structures.py:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/packaging/markers.py:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/packaging/__about__.py:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/packaging/_compat.py:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/packaging/specifiers.py:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/__init__.py:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/__pycache__/appdirs.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/__pycache__/six.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/__pycache__/pyparsing.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/appdirs.py:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/six.py:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/_vendor/pyparsing.py:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/py31compat.py:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/__init__.py:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/__pycache__/py31compat.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/extern/__init__.py:0
# ./.venv/lib/python3.7/site-packages/pkg_resources/extern/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/pyzmq-22.3.0.dist-info/AUTHORS.md:0
# ./.venv/lib/python3.7/site-packages/pyzmq-22.3.0.dist-info/RECORD:0
# ./.venv/lib/python3.7/site-packages/pyzmq-22.3.0.dist-info/COPYING.BSD:0
# ./.venv/lib/python3.7/site-packages/pyzmq-22.3.0.dist-info/WHEEL:0
# ./.venv/lib/python3.7/site-packages/pyzmq-22.3.0.dist-info/COPYING.LESSER:0
# ./.venv/lib/python3.7/site-packages/pyzmq-22.3.0.dist-info/top_level.txt:0
# ./.venv/lib/python3.7/site-packages/pyzmq-22.3.0.dist-info/INSTALLER:0
# ./.venv/lib/python3.7/site-packages/pyzmq-22.3.0.dist-info/METADATA:0
# ./.venv/lib/python3.7/site-packages/parso/tree.py:0
# ./.venv/lib/python3.7/site-packages/parso/python/prefix.py:0
# ./.venv/lib/python3.7/site-packages/parso/python/grammar37.txt:0
# ./.venv/lib/python3.7/site-packages/parso/python/tree.py:0
# ./.venv/lib/python3.7/site-packages/parso/python/grammar36.txt:0
# ./.venv/lib/python3.7/site-packages/parso/python/token.py:0
# ./.venv/lib/python3.7/site-packages/parso/python/grammar310.txt:0
# ./.venv/lib/python3.7/site-packages/parso/python/grammar311.txt:0
# ./.venv/lib/python3.7/site-packages/parso/python/grammar312.txt:0
# ./.venv/lib/python3.7/site-packages/parso/python/__init__.py:0
# ./.venv/lib/python3.7/site-packages/parso/python/__pycache__/tree.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/python/__pycache__/parser.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/python/__pycache__/pep8.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/python/__pycache__/token.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/python/__pycache__/diff.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/python/__pycache__/tokenize.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/python/__pycache__/errors.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/python/__pycache__/prefix.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/python/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/python/parser.py:0
# ./.venv/lib/python3.7/site-packages/parso/python/pep8.py:0
# ./.venv/lib/python3.7/site-packages/parso/python/diff.py:0
# ./.venv/lib/python3.7/site-packages/parso/python/errors.py:0
# ./.venv/lib/python3.7/site-packages/parso/python/tokenize.py:0
# ./.venv/lib/python3.7/site-packages/parso/python/grammar38.txt:0
# ./.venv/lib/python3.7/site-packages/parso/python/grammar39.txt:0
# ./.venv/lib/python3.7/site-packages/parso/cache.py:0
# ./.venv/lib/python3.7/site-packages/parso/__init__.py:0
# ./.venv/lib/python3.7/site-packages/parso/__pycache__/tree.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/__pycache__/normalizer.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/__pycache__/parser.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/__pycache__/grammar.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/__pycache__/_compatibility.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/__pycache__/file_io.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/__pycache__/cache.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/__pycache__/utils.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/grammar.py:0
# ./.venv/lib/python3.7/site-packages/parso/parser.py:0
# ./.venv/lib/python3.7/site-packages/parso/utils.py:0
# ./.venv/lib/python3.7/site-packages/parso/py.typed:0
# ./.venv/lib/python3.7/site-packages/parso/file_io.py:0
# ./.venv/lib/python3.7/site-packages/parso/normalizer.py:0
# ./.venv/lib/python3.7/site-packages/parso/_compatibility.py:0
# ./.venv/lib/python3.7/site-packages/parso/pgen2/__init__.py:0
# ./.venv/lib/python3.7/site-packages/parso/pgen2/__pycache__/grammar_parser.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/pgen2/__pycache__/generator.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/pgen2/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/parso/pgen2/generator.py:0
# ./.venv/lib/python3.7/site-packages/parso/pgen2/grammar_parser.py:0
# ./.venv/lib/python3.7/site-packages/pip-19.0.3.dist-info/RECORD:0
# ./.venv/lib/python3.7/site-packages/pip-19.0.3.dist-info/WHEEL:0
# ./.venv/lib/python3.7/site-packages/pip-19.0.3.dist-info/entry_points.txt:0
# ./.venv/lib/python3.7/site-packages/pip-19.0.3.dist-info/top_level.txt:0
# ./.venv/lib/python3.7/site-packages/pip-19.0.3.dist-info/LICENSE.txt:0
# ./.venv/lib/python3.7/site-packages/pip-19.0.3.dist-info/INSTALLER:0
# ./.venv/lib/python3.7/site-packages/pip-19.0.3.dist-info/METADATA:0
# ./.venv/lib/python3.7/site-packages/psutil/_psutil_osx.cpython-37m-darwin.so:0
# ./.venv/lib/python3.7/site-packages/psutil/_pswindows.py:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/test_contracts.py:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/test_connections.py:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/runner.py:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/test_unicode.py:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/test_misc.py:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/test_posix.py:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/test_linux.py:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/test_sunos.py:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/__init__.py:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/__pycache__/test_osx.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/__pycache__/test_sunos.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/__pycache__/test_misc.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/__pycache__/test_contracts.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/__pycache__/test_memleaks.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/__pycache__/test_bsd.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/__pycache__/test_aix.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/__pycache__/test_windows.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/__pycache__/test_linux.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/__pycache__/__main__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/__pycache__/test_system.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/__pycache__/test_connections.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/__pycache__/test_posix.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/__pycache__/test_testutils.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/__pycache__/test_unicode.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/__pycache__/test_process.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/__pycache__/runner.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/test_aix.py:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/test_process.py:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/test_bsd.py:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/test_system.py:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/test_osx.py:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/test_memleaks.py:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/test_windows.py:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/__main__.py:0
# ./.venv/lib/python3.7/site-packages/psutil/tests/test_testutils.py:0
# ./.venv/lib/python3.7/site-packages/psutil/_common.py:0
# ./.venv/lib/python3.7/site-packages/psutil/__init__.py:0
# ./.venv/lib/python3.7/site-packages/psutil/__pycache__/_pslinux.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/__pycache__/_pssunos.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/__pycache__/_psosx.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/__pycache__/_compat.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/__pycache__/_common.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/__pycache__/_psbsd.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/__pycache__/_psposix.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/__pycache__/_pswindows.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/__pycache__/_psaix.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/psutil/_psutil_posix.cpython-37m-darwin.so:0
# ./.venv/lib/python3.7/site-packages/psutil/_psosx.py:0
# ./.venv/lib/python3.7/site-packages/psutil/_psbsd.py:0
# ./.venv/lib/python3.7/site-packages/psutil/_psaix.py:0
# ./.venv/lib/python3.7/site-packages/psutil/_pslinux.py:0
# ./.venv/lib/python3.7/site-packages/psutil/_compat.py:0
# ./.venv/lib/python3.7/site-packages/psutil/_psposix.py:0
# ./.venv/lib/python3.7/site-packages/psutil/_pssunos.py:0
# ./.venv/lib/python3.7/site-packages/traitlets/_version.py:0
# ./.venv/lib/python3.7/site-packages/traitlets/config/sphinxdoc.py:0
# ./.venv/lib/python3.7/site-packages/traitlets/config/configurable.py:0
# ./.venv/lib/python3.7/site-packages/traitlets/config/tests/test_loader.py:0
# ./.venv/lib/python3.7/site-packages/traitlets/config/tests/__init__.py:0
# ./.venv/lib/python3.7/site-packages/traitlets/config/tests/__pycache__/test_application.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/traitlets/config/tests/__pycache__/test_configurable.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/traitlets/config/tests/__pycache__/test_loader.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/traitlets/config/tests/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/traitlets/config/tests/test_configurable.py:0
# ./.venv/lib/python3.7/site-packages/traitlets/config/tests/test_application.py:0
# ./.venv/lib/python3.7/site-packages/traitlets/config/__init__.py:0
# ./.venv/lib/python3.7/site-packages/traitlets/config/__pycache__/loader.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/traitlets/config/__pycache__/application.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/traitlets/config/__pycache__/configurable.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/traitlets/config/__pycache__/sphinxdoc.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/traitlets/config/__pycache__/manager.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/traitlets/config/__pycache__/__init__.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/traitlets/config/application.py:0
# ./.venv/lib/python3.7/site-packages/traitlets/config/loader.py:0
# ./.venv/lib/python3.7/site-packages/traitlets/config/manager.py:0
# ./.venv/lib/python3.7/site-packages/traitlets/log.py:0
# ./.venv/lib/python3.7/site-packages/traitlets/tests/test_traitlets.py:0
# ./.venv/lib/python3.7/site-packages/traitlets/tests/__init__.py:0
# ./.venv/lib/python3.7/site-packages/traitlets/tests/_warnings.py:0
# ./.venv/lib/python3.7/site-packages/traitlets/tests/__pycache__/test_traitlets_enum.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/traitlets/tests/__pycache__/test_traitlets.cpython-37.pyc:0
# ./.venv/lib/python3.7/site-packages/traitlets/tests/__pycache__/utils.cpython-37.pyc:0

# %%
history
# Out:
#    53  ls
#    54  la
#    55  ..
#    56  la
#    57  cd Flask_Blog/
#    58  ls
#    59  python3 -m venv .venv
#    60  ae
#    61  pip3 install -r requirements.txt
#    62  ls
#    63  cd 08-Posts/
#    64  ls
#    65  flask run
#    66  python run.py
#    67  pyhton
#    68  import json
#    69  pip list
#    70  python
#    71  chrome
#    72  chrome -h
#    73  chrome -n
#    74  chrome
#    75  man chrome
#    76  chrome
#    77  chrome
#    78  passdb
#    79  source /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/activate
#    80  /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#    81  /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python
#    82  source /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/activate
#    83   /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 56753 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#    84   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 56763 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#    85   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 56769 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#    86   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 56787 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#    87   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 56797 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#    88   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 56804 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#    89   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 56828 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#    90   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 56838 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#    91   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 56879 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#    92   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 57305 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#    93   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 57318 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#    94   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 57335 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#    95   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 57342 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#    96   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 57348 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#    97   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 57355 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#    98   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 57363 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#    99   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 57372 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#   100   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 57381 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#   101   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 57413 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#   102   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 57421 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#   103  which python
#   104  python -V
#   105   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 57439 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#   106   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 57450 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#   107   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 57463 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#   108   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 57470 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#   109   cd /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures ; /usr/bin/env /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/.venv/bin/python /Users/a.momin/.vscode/extensions/ms-python.python-2022.2.1924087327/pythonFiles/lib/python/debugpy/launcher 57475 -- /Users/a.momin/gd/Software_Development/Python_Program/Python3/Algorithms_and_Data_Structures/ads/exercises/heaps/heaps.py
#   110  ae
#   111  ls
#   112  ..
#   113  cd flask-app/
#   114  de
#   115  wd
#   116  cd flask-course/
#   117  ls
#   118  cd flask-app/
#   119  ls
#   120  chrome
#   121  ae
#   122  jnb
#   123  de
#   124  chrome
#   125  passdb
#   126  chrome
#   127  chrome
#   128  brew install --cask gotomeeting
#   129  brew install --cask teamviewer
#   130  open /usr/local/Caskroom/teamviewer/15.28.5/Install TeamViewer.app/Contents/Resources
#   131  open /usr/local/Caskroom/teamviewer/15.28.5/Install
#   132  open /usr/local/Caskroom/teamviewer/15.28.5/
#   133  open /usr/local/Caskroom/teamviewer
#   134  open /usr/local/Caskroom/
#   135  open /usr/local/
#   136  man python
#   137  h
#   138  brew install --cask microsoft-teams
#   139  cd $JOBS_DB
#   140  ls
#   141  ls Data-Science/
#   142  code -n Data-Science/data-science-process.md
#   143  code -n Data-Science/data-science-process.md
#   144  chrome
#   145  cmdvsc
#   146  ntvsc
#   147  cmdpy
#   148  conda search python
#   149  cmdpy
#   150  ntre
#   151  code ~/.aliases
#   152  python
#   153  jt -t grade3
#   154  jt -t grade3
#   155  jt -t gruvboxd
#   156  which python
#   157  passdb
#   158  pip3 list
#   159  pip list
#   160  cd $JOBS_DB
#   161  LS
#   162  open .
#   163  open .
#   164  ls
#   165  cd pyt
#   166  cd Python-Developer/
#   167  ls
#   168  code .
#   169  mlcourses
#   170  chroem
#   171  chrome
#   172  cae fastai
#   173  nb
#   174  jnb
#   175  cde
#   176  ads
#   177  de
#   178  pip list
#   179  pip3 list
#   180  ae
#   181  pip3 list
#   182  jnb
#   183  pip3 list
#   184  pip3 list
#   185  conda list
#   186  jnb
#   187  de
#   188  pip list
#   189  pip3 list
#   190  wd
#   191  code Javascript_Program/
#   192  jsp
#   193  wd
#   194  cd flask-course/flask-app/
#   195  ls
#   196  ae
#   197  ..
#   198  cd Flask_Blog/
#   199  ae
#   200  code .
#   201  cd 09-Pagination/
#   202  ls
#   203  python run.py
#   204  wd
#   205  cd flask-course/flask-app/
#   206  ls
#   207  la
#   208  code .
#   209  cmdjnb
#   210  ae
#   211  pip install ipykernel
#   212  ipython kernel install --user --name=flask_jnb_kernel
#   213  chrome
#   214  flask run
#   215  chrome
#   216  de
#   217  pp3
#   218  wd
#   219  code scraping/
#   220  pp3
#   221  code elements-of-programming-interview/
#   222  wd
#   223  cd flask-course/flask-app/
#   224  ls
#   225  la
#   226  code .
#   227  flask run
#   228  code ~/.bash_profile
#   229  ae
#   230  flask run
#   231  ae
#   232  jnb
#   233  de
#   234  de
#   235  ads
#   236  code .
#   237  code .
#   238  code ~/.bash_profile
#   239  ls
#   240  code .
#   241  pp3
#   242  code elements-of-programming-interview/
#   243  python
#   244  ls
#   245  cd EPIJudge/
#   246  ls
#   247  cat README.md
#   248  tput rmam
#   249  cat README.md
#   250  cat README.md
#   251  tput smam
#   252  cat README.md
#   253  cat README.md
#   254  tput rmam
#   255  cat README.md
#   256  tput smam
#   257  cat README.md
#   258  ntjnb
#   259  cmdjnb
#   260  ntpy
#   261  cmdpy
#   262  source ~/.aliases
#   263  ntpy
#   264  code ~/.bash_profile
#   265  chrome
#   266  passdb
#   267  jobdb
#   268  chrome
#   269  passdb
#   270  wd
#   271  code django-courses/
#   272  cd $JOBS_DB
#   273  LS
#   274  cd Data-Science/
#   275  ls
#   276  touch data-science-process.md
#   277  code data-science-process.md
#   278  code -n
#   279  cmdmac
#   280  nts
#   281  code ~/.aliases
#   282  chrome
#   283  passdb
#   284  passdb
#   285  chrome
#   286  python
#   287  passdb
#   288  passdb
#   289  ls
#   290  ..
#   291  code .
#   292  chrome
#   293  pp3
#   294  wd
#   295  code betterpython/
#   296  ads
#   297  ls
#   298  pip install ipykernel
#   299  ipython kernel install --user --name=ads_jnb_kernel
#   300  ls
#   301  pip install -h
#   302  pip install -e .
#   303  python3 -m pip install --upgrade
#   304  python3 -m pip install --upgrade pip
#   305  ls
#   306  pip list
#   307  pip3 list
#   308  de
#   309  pip3 list
#   310  pip list
#   311  which pip
#   312  python3.9
#   313  python39
#   314  python
#   315  pip list
#   316  pip uninstall ads
#   317  pip list
#   318  ls
#   319  rm -fr ads.egg-info/
#   320  ls
#   321  source ~/.bash_PR
#   322  source ~/.bash_profile
#   323  python
#   324  source ~/.bash_profile
#   325  python
#   326  python
#   327  wd
#   328  cd flask-course/Flask_Blog/
#   329  ls
#   330  ae
#   331  code .
#   332  code ~/.jupyter/custom/custom.jS
#   333  jupyter notebook -h
#   334  jupyter notebook --help-all
#   335  jupyter notebook -h
#   336  jupyter notebook --show-config
#   337  code /Users/a.momin/.jupyter/jupyter_notebook_config.json
#   338  code /Library/Frameworks/Python.framework/Versions/3.7/etc/jupyter/jupyter_notebook_config.json
#   339  ls
#   340  conda list
#   341  cae fastai
#   342  conda list
#   343  pip list
#   344  which pip
#   345  pip -V
#   346  mlcourses
#   347  fastai
#   348  cae fastai
#   349  chrome
#   350  jnb
#   351  chrome
#   352  jnb
#   353  source ~/.bash_profile
#   354  cae fastai
#   355  jnb
#   356  source ~/.bash_profile
#   357  source ~/.bash_profile
#   358  ae
#   359  code .
#   360  ls
#   361  git log
#   362  git diff
#   363  ntgit
#   364  git status
#   365  git add .
#   366  git commit -m "Adds pagination"
#   367  git status
#   368  tree
#   369  pip list
#   370  ae
#   371  python -V
#   372  pip -V
#   373  which python
#   374  cho $PATH
#   375  echo $PATH
#   376  cat ~/.bash_profile
#   377  de
#   378  de
#   379  wd
#   380  cd flask-course/flask-app/
#   381  ae
#   382  flask run
#   383  source ~/.bash_profile
#   384  flask run
#   385  ae
#   386  de
#   387  source ~/.bash_profile
#   388  ae
#   389  flask run
#   390  wd
#   391  cd flask-course/flask-app/
#   392  ls
#   393  ..
#   394  cd flask-app/
#   395  ls
#   396  jnb
#   397  jnb
#   398  source ~/.bash_profile
#   399  ae
#   400  jnb
#   401  source ~/.bash_profile
#   402  source ~/.bash_profile
#   403  ae
#   404  jnb
#   405  wd
#   406  cd flask-course/flask-app/
#   407  ls
#   408  chrome
#   409  conda list
#   410  conda env list
#   411  cae sql
#   412  jnb
#   413  de
#   414  cae fastai
#   415  jnb
#   416  cd $JOBS_DB
#   417  ls
#   418  open .
#   419  open .
#   420  hrome
#   421  chrome
#   422  open .
#   423  chrome
#   424  open .
#   425  chrome
#   426  open .
#   427  GDT
#   428  cd $GDT
#   429  ls
#   430  gd
#   431  open .
#   432  open .
#   433  ls
#   434  cd Jobs_DB/
#   435  ls
#   436  ls Python-Developer/
#   437  ls
#   438  code Python-Developer/python_developer_job.md
#   439  code Python-Developer/python_job_description.md
#   440  code -n Python-Developer/python_job_description.md
#   441  chrome
#   442  open .
#   443  open .
#   444  chrome
#   445  open .
#   446  chrome
#   447  open .
#   448  wd
#   449  code fast_API/
#   450  passdb
#   451  cd fast_API/
#   452  ls
#   453  cd fastapi-course/
#   454  git log
#   455  ntre
#   456  git checkout Lesson 8
#   457  ntgit
#   458  git log --oneline
#   459  git checkout 9544e24
#   460  git checkout 2cfe650
#   461  ads
#   462  code .
#   463  mysql -u root -p
#   464  mysql -u A.Momin -p
#   465  de
#   466  chrome
#   467  ntds
#   468  conda env list
#   469  source activate sql
#   470  ls
#   471  cd $DS
#   472  ls
#   473  cd bash_scripting/
#   474  ls
#   475  conda env list
#   476  conda create -n bash_kernel -y
#   477  cae bash_kernel
#   478  conda install bash_kernel -c conda-forge
#   479  ls
#   480  jnb
#   481  cde
#   482  ls
#   483  conda env list
#   484  PS1='[PEXP\[\]ECT_PROMPT>' PS2='[PEXP\[\]ECT_PROMPT+' PROMPT_COMMAND=''
#   485  export PAGER=cat
#   486  display () {     TMPFILE=$(mktemp ${TMPDIR-/tmp}/bash_kernel.XXXXXXXXXX);     cat > $TMPFILE;     echo "bash_kernel: saved image data to: $TMPFILE" >&2; }
#   487  compgen -cdfa l
#   488  compgen -cdfa ls
#   489  ls
#   490  echo $?
#   491  compgen -cdfa *.py
#   492  find . type f –iname *.py
#   493  echo $?
#   494  compgen -cdfa *.
#   495  compgen -cdfa *.
#   496  compgen -cdfa *.
#   497  compgen -cdfa *.p
#   498  compgen -cdfa *.py
#   499  compgen -cdfa *.py
#   500  compgen -cdfa *.py
#   501  PS1='[PEXP\[\]ECT_PROMPT>' PS2='[PEXP\[\]ECT_PROMPT+' PROMPT_COMMAND=''
#   502  export PAGER=cat
#   503  display () {     TMPFILE=$(mktemp ${TMPDIR-/tmp}/bash_kernel.XXXXXXXXXX);     cat > $TMPFILE;     echo "bash_kernel: saved image data to: $TMPFILE" >&2; }
#   504  grep "Jane Williams" data/names.txt
#   505  echo $?
#   506  grep "John Williams" names.txt
#   507  echo $?
#   508  grep "Jane Williams" data/names.txt
#   509  echo $?
#   510  compgen -cdfa .
#   511  compgen -cdfa ./
#   512  grep "Jane Williams" ./data/names.txt
#   513  echo $?
#   514  compgen -cdfa .
#   515  compgen -cdfa .d
#   516  compgen -cdfa .da
#   517  compgen -cdfa .dat
#   518  compgen -cdfa .data
#   519  compgen -cdfa .data/
#   520  compgen -cdfa /
#   521  compgen -cdfa .
#   522  grep "John Williams" ./data/names.txt
#   523  echo $?
#   524  compgen -cdfa ./data/
#   525  grep -w "John Williams" ./data/names.txt
#   526  echo $?
#   527  compgen -cdfa ./data/
#   528  grep -wi "John Williams" ./data/names.txt
#   529  echo $?
#   530  compgen -cdfa ./data/
#   531  grep -win "John Williams" ./data/names.txt
#   532  echo $?
#   533  compgen -cdfa ./data/
#   534  grep -win -B 4 "John Williams" ./data/names.txt
#   535  echo $?
#   536  compgen -cdfa ./data/
#   537  grep -win -A 4 "John Williams" ./data/names.txt
#   538  echo $?
#   539  compgen -cdfa ./data/
#   540  grep -win -C 2 "John Williams" ./data/names.txt
#   541  echo $?
#   542  grep -win "John Williams" ./*
#   543  echo $?
#   544  grep -win "John Williams" ./*.txt
#   545  echo $?
#   546  grep -winr "John Williams" .
#   547  echo $?
#   548  grep -wirl "John Williams" .
#   549  echo $?
#   550  grep -wirc "John Williams" .
#   551  echo $?
#   552  history

# %%
history | grep "git commit"
# Out:
#   366  git commit -m "Adds pagination"
#   554  history | grep "git commit"

# %%
history | grep "git commit" | grep "dotfile"
# Out:
#   556  history | grep "git commit" | grep "dotfile"

# %%
grep "...-...-...." ./data/names.txt
# Out:
# 836-555-5439
# 442-555-9487
# 886-555-6636
# 489-555-4991
# 366-555-4305
# 701-555-5108
# 678-555-3299
# 788-555-3577
# 201-555-1871
# 119-555-3358
# 304-555-4321
# 170-555-1113
# 776-555-2543
# 327-555-2942
# 119-555-4718
# 464-555-7896
# 818-555-1266
# 415-555-9458
# 392-555-3874
# 340-555-8167
# 179-555-1774
# 498-555-9480
# 690-555-2999
# 888-555-1673
# 630-555-2067
# 712-555-9542
# 120-555-4236
# 371-555-6917
# 992-555-2186
# 394-555-2588
# 359-555-7817
# 688-555-3426
# 561-555-3471
# 162-555-7584
# 393-555-4428
# 932-555-6680
# 941-555-7991
# 738-555-8653
# 339-555-2218
# 102-555-2595
# 567-555-3369
# 708-555-9108
# 372-555-4410
# 347-555-7324
# 733-555-1459
# 947-555-2683
# 230-555-6950
# 448-555-3853
# 462-555-6266
# 880-555-3943
# 653-555-5931
# 360-555-9136
# 150-555-9821
# 635-555-8559
# 901-555-6527
# 920-555-3034
# 828-555-5360
# 903-555-1543
# 586-555-8861
# 313-555-3643
# 953-555-4012
# 400-555-4196
# 895-555-1208
# 477-555-9321
# 868-555-4104
# 780-555-3985
# 332-555-4446
# 327-555-2338
# 536-555-9505
# 533-555-3337
# 228-555-1646
# 412-555-8707
# 140-555-8907
# 803-555-9277
# 325-555-3878
# 163-555-5544
# 296-555-2333
# 402-555-7629
# 764-555-9533
# 426-555-4166
# 682-555-7689
# 370-555-2513
# 960-555-4733
# 247-555-5137
# 567-555-9724
# 218-555-5260
# 515-555-4529
# 273-555-9174
# 734-555-7873
# 120-555-3239
# 515-555-4321
# 419-555-2791
# 851-555-3841
# 785-555-6641
# 610-555-2270
# 237-555-4632
# 142-555-4094
# 599-555-8340
# 851-555-6015
# 782-555-3582
# 689-555-2182
# 869-555-5446

# %%
grep -P "\d{3}-\d{3}-\d{4}" ./data/names.txt
# Out:
# 836-555-5439
# 442-555-9487
# 886-555-6636
# 489-555-4991
# 366-555-4305
# 701-555-5108
# 678-555-3299
# 788-555-3577
# 201-555-1871
# 119-555-3358
# 304-555-4321
# 170-555-1113
# 776-555-2543
# 327-555-2942
# 119-555-4718
# 464-555-7896
# 818-555-1266
# 415-555-9458
# 392-555-3874
# 340-555-8167
# 179-555-1774
# 498-555-9480
# 690-555-2999
# 888-555-1673
# 630-555-2067
# 712-555-9542
# 120-555-4236
# 371-555-6917
# 992-555-2186
# 394-555-2588
# 359-555-7817
# 688-555-3426
# 561-555-3471
# 162-555-7584
# 393-555-4428
# 932-555-6680
# 941-555-7991
# 738-555-8653
# 339-555-2218
# 102-555-2595
# 567-555-3369
# 708-555-9108
# 372-555-4410
# 347-555-7324
# 733-555-1459
# 947-555-2683
# 230-555-6950
# 448-555-3853
# 462-555-6266
# 880-555-3943
# 653-555-5931
# 360-555-9136
# 150-555-9821
# 635-555-8559
# 901-555-6527
# 920-555-3034
# 828-555-5360
# 903-555-1543
# 586-555-8861
# 313-555-3643
# 953-555-4012
# 400-555-4196
# 895-555-1208
# 477-555-9321
# 868-555-4104
# 780-555-3985
# 332-555-4446
# 327-555-2338
# 536-555-9505
# 533-555-3337
# 228-555-1646
# 412-555-8707
# 140-555-8907
# 803-555-9277
# 325-555-3878
# 163-555-5544
# 296-555-2333
# 402-555-7629
# 764-555-9533
# 426-555-4166
# 682-555-7689
# 370-555-2513
# 960-555-4733
# 247-555-5137
# 567-555-9724
# 218-555-5260
# 515-555-4529
# 273-555-9174
# 734-555-7873
# 120-555-3239
# 515-555-4321
# 419-555-2791
# 851-555-3841
# 785-555-6641
# 610-555-2270
# 237-555-4632
# 142-555-4094
# 599-555-8340
# 851-555-6015
# 782-555-3582
# 689-555-2182
# 869-555-5446

# %%
grep -V
# Out:
# grep (GNU grep) 3.7
# Packaged by Homebrew
# Copyright (C) 2021 Free Software Foundation, Inc.
# License GPLv3+: GNU GPL version 3 or later <https://gnu.org/licenses/gpl.html>.
# This is free software: you are free to change and redistribute it.
# There is NO WARRANTY, to the extent permitted by law.
#
# Written by Mike Haertel and others; see
# <https://git.sv.gnu.org/cgit/grep.git/tree/AUTHORS>.

# %% [markdown]
# #### [getopts](https://linuxhint.com/bash_getopts_example/)

# %% [markdown]
# ##### Tutorials:
#
# - [Command Line Arguments with getopts](https://www.youtube.com/watch?v=5O4SLIDSMqg&t=314s)

# %%
function main(){
    check $@
    
    if [ $m ] then
        echo "'m' has been chosen."
    fi
}

check(){
    local OPTIND opt i 
    
    while getopts ":cmni:" opt; do
        case $opt in 
            i) echo "You chose 'i'";input="$OPTARG";;
            c) echo "'c' is a good option.";;
            m) m=true;;
            n) n_func;;
            \?) help;exit 1;;
        esac
    done
    
    shift $((OPTIND -1))
    
    if [ "$input" = "" ]; then
        echo "No input files" 
    else
        echo "Input is $input"
    fi
}

function help(){
    echo "Help. I need help"
}

function n_func(){
    echo "This is the n_func."
}

# %% [markdown]
# #### Stream Editor:
# - [sed - GNU](https://www.gnu.org/software/sed/manual/sed.html#sed-addresses)
# - [50 sed Commands Examples](https://linuxhint.com/50_sed_command_examples/)
# - [sed - Wikipedia](https://en.wikipedia.org/wiki/Sed#File-based_sed_scripts)

# %%
file=config2

# %%
wc -w $file
# Out:
#       80 config2

# %% [markdown]
# ##### Substitution command

# %% [markdown]
# ```bash
# sed 's/regexp/replacement/g' inputFileName
# ```
#
# - `s` stands for substitute
# - `g` stands for global
# - `/` delimiting symbol
# - Use `-i` with `.bak` on `mac` to replace on the given file.
# - without `/g` flag it matches only the first occurance of each line.
# - Use double quotes if the replacement-line is not fixed, e.g. it's a variable, like this: sed -i "Ns/.*/foo=$myVar" file.txt

# %%
sed 's/Command/COMMAND/g' $file > $file

# %%
# sed 's/*\<li\>banana\<\/li\>*/\<li\>MANGO\<\/li\>/' $file > $file

# %% [markdown]
# The commands in the following cell replace the line 2 `$file` by `HostName $my_ip` and remove the backup file (*.bak).

# %%
my_ip=222222222222
sed -i .bak "2s/.*/HostName $my_ip/" $file
rm *.bak

# %%
sed '2s/^HostName\s[1-9]{2}[.][1-9]{3}[.][1-9]{3}[.][1-9]{3}/HostName 1111111111111/' $file > config3

# %%
sed -i .bak '2s/^HostName\s[1-9]\d\.\d{3}\.\d{3}\.\d{3}/HostName 1111111111111/' $file

# %% [markdown]
# The following command replaces the word ‘hello’ with ‘world’ only on line 144:

# %%
sed '2s/HostName/HostName/' input.txt > output.txt

# %% [markdown]
# The following command replaces the word ‘hello’ with ‘world’ only in lines 4 to 17 (inclusive):

# %%
sed '4,17s/hello/world/' input.txt > output.txt

# %% [markdown]
# The following command prints lines in config file which end with `sm`:

# %%
sed -n '/sm$/p' config
# Out:
# Host sm

# %%
find ../data -name '.md' | xargs sed -i .bac 's/command/COMMAND/g'

# %%
ls
# Out:
# README.md
# bash_programming.ipynb
# my_bash_script
# pure-bash-bible
# sys_check

# %% [markdown]
# ##### Other sed commands

# %% [markdown]
# The following uses the `d` command to filter out lines that only contain spaces, or only contain the end of line character:
# ```bash
# sed '/^ *$/d' inputFileName
# ```
# This example uses some of the following regular expression metacharacters (sed supports the full range of regular expressions):
#
# - The caret `^` matches the beginning of the line.
# - The dollar sign `$` matches the end of the line.
# - The asterisk `*` matches zero or more occurrences of the previous character.
# - The plus `+` matches one or more occurrence(s) of the previous character.
# - The question mark `?` matches zero or one occurrence of the previous character.
# - The dot `.` matches exactly one character.

# %% [markdown]
# #### [awk](https://en.wikipedia.org/wiki/AWK)

# %% [markdown]
# #### Extended Arguments:  [xargs](https://en.wikipedia.org/wiki/Xargs)

# %%
find ../data -name '*.csv' | xargs echo
# Out:
# ../data/test_file.csv ../data/auction.csv ../data/save_states.csv

# %%
pwd
