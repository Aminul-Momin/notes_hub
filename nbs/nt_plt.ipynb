# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Basic-APIs:" data-toc-modified-id="Basic-APIs:-1">Basic APIs:</a></span></li><li><span><a href="#Basic-Plots" data-toc-modified-id="Basic-Plots-2">Basic Plots</a></span></li><li><span><a href="#Legends,-Linestyles,-Colors-and-Markers" data-toc-modified-id="Legends,-Linestyles,-Colors-and-Markers-3">Legends, Linestyles, Colors and Markers</a></span></li><li><span><a href="#Suplots" data-toc-modified-id="Suplots-4">Suplots</a></span></li><li><span><a href="#-Analysis-of-Figure-Object-" data-toc-modified-id="-Analysis-of-Figure-Object--5"><b style="color:orange"> Analysis of Figure Object </b></a></span></li><li><span><a href="#Multiple-y-Axis" data-toc-modified-id="Multiple-y-Axis-6">Multiple y-Axis</a></span></li><li><span><a href="#Shared-Axes" data-toc-modified-id="Shared-Axes-7">Shared Axes</a></span></li><li><span><a href="#Bar-Plot" data-toc-modified-id="Bar-Plot-8">Bar Plot</a></span></li><li><span><a href="#Contour-Plot" data-toc-modified-id="Contour-Plot-9">Contour Plot</a></span></li><li><span><a href="#Quiver-Plot" data-toc-modified-id="Quiver-Plot-10">Quiver Plot</a></span></li><li><span><a href="#-3D-Plot" data-toc-modified-id="-3D-Plot-11"> <a style="color:orange" id="3d" rel="nofollow">3D Plot</a></a></span></li><li><span><a href="#3D-Faces" data-toc-modified-id="3D-Faces-12">3D Faces</a></span></li><li><span><a href="#Color-Map" data-toc-modified-id="Color-Map-13">Color Map</a></span><ul class="toc-item"><li><span><a href="#A-simple-pcolor-demo:" data-toc-modified-id="A-simple-pcolor-demo:-13.1">A simple pcolor demo:</a></span></li><li><span><a href="#Comparing-pcolor-with-similar-functions:" data-toc-modified-id="Comparing-pcolor-with-similar-functions:-13.2">Comparing pcolor with similar functions:</a></span></li></ul></li><li><span><a href="#Box-Plot" data-toc-modified-id="Box-Plot-14">Box Plot</a></span></li><li><span><a href="#Correlation-Matrix-Heatmap" data-toc-modified-id="Correlation-Matrix-Heatmap-15">Correlation Matrix <a href="https://matplotlib.org/stable/gallery/images_contours_and_fields/image_annotated_heatmap.html#sphx-glr-gallery-images-contours-and-fields-image-annotated-heatmap-py" rel="nofollow" target="_blank">Heatmap</a></a></span></li><li><span><a href="#IPython-Widgets" data-toc-modified-id="IPython-Widgets-16">IPython Widgets</a></span></li><li><span><a href="#Matplotlib-Widgets" data-toc-modified-id="Matplotlib-Widgets-17">Matplotlib Widgets</a></span></li><li><span><a href="#Overview-of-seaborn-plotting-functions" data-toc-modified-id="Overview-of-seaborn-plotting-functions-18"><a href="https://seaborn.pydata.org/tutorial/function_overview.html" rel="nofollow" target="_blank">Overview of seaborn plotting functions</a></a></span></li></ul></div>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

from sklearn import datasets as ds

import random
plt.style.use('seaborn')

styles = plt.style.available
# for style in styles: print(style)
# Out:
# /var/folders/f4/qkdf_4lj59l90mh4fqh_rtvr0000gn/T/ipykernel_2945/862239589.py:10: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# ```python
#     +----------------------------------++------------------------------------+
#     |          LINE STYLES             ||               MARKERS              |
#     +----------------------------------++------------------------------------+
#     | Character   | Description        ||     Character |  Description       |
#     +----------------------------------++------------------------------------+
#     |  '-'   =>>  solid line style     ||   '.'   =>>   point marker         |
#     |  '--'  =>>  dashed line style    ||   ','   =>>   pixel marker         |
#     |  '-.'  =>>  dash-dot line style  ||   'o'   =>>   circle marker        |
#     |  ':'   =>>  dotted line style    ||   'v'   =>>   triangle_down marker |
#     +----------------------------------||   '^'   =>>   triangle_up marker   |
#                                        ||   '<'   =>>   triangle_left marker |
#     +----------------------------------||   '>'   =>>   triangle_right marker|
#     |            COLORS                ||   '1'   =>>   tri_down marker      |
#     +----------------------------------||   '2'   =>>   tri_up marker        |
#     |  Character   ||     Color        ||   '3'   =>>   tri_left marker      |
#     +----------------------------------||   '4'   =>>   tri_right marker     |
#     |   'b'   =>>   blue               ||   's'   =>>   square marker        |
#     |   'g'   =>>   green              ||   'p'   =>>   pentagon marker      |
#     |   'r'   =>>   red                ||   '*'   =>>   star marker          |
#     |   'c'   =>>   cyan               ||   'h'   =>>   hexagon1 marker      |
#     |   'm'   =>>   magenta            ||   'H'   =>>   hexagon2 marker      |
#     |   'y'   =>>   yellow             ||   '+'   =>>   plus marker          |
#     |   'k'   =>>   black              ||   'x'   =>>   x marker             |
#     |   'w'   =>>   white              ||   'D'   =>>   diamond marker       |
#     +----------------------------------+|   'd'   =>>   thin_diamond marker  |
#                                         |   '|'   =>>   vline marker         |
#                                         |   '_'   =>>   hline marker         |
#                                         +------------------------------------+
# ```

# %% [markdown]
# # <b style="color:tomato"> Matplotlib Tutorial</b>
#
# This notebook will show you how to draw basic plots using `matplotlib`.

# %% [markdown]
# - [Matplotlib Usage Guide](https://matplotlib.org/stable/tutorials/introductory/usage.html#sphx-glr-tutorials-introductory-usage-py)

# %% [markdown]
# ## Basic APIs:

# %%
from matplotlib.figure import Figure
from  matplotlib.axes import Axes
import matplotlib.pyplot as plt

# %%
# dir(Figure)

# %%
# dir(Axes)

# %%
# dir(plt)

# %%
# help(plt)

# %%
fig, axes = plt.subplots(2,2,tight_layout=True)
axes[0,0].set_title('Title', c='blue')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
# dir(fig)

# %%
axes[0].set_title('Axes Title')
# Out:
# ----------------------------------------------------------------
# AttributeError                 Traceback (most recent call last)
# <ipython-input-24-26b10be92113> in <module>
# ----> 1 axes[0].set_title('Axes Title')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'set_title'

# %% [markdown]
# ## Basic Plots

# %%
# Data
x = np.arange(0, 4 * np.pi, 0.1) # x in [0, 4 * pi) 
y_cos = np.cos(x)

fig = plt.figure(tight_layout=True)
plt.plot(x, y_cos)

plt.xlabel('$x$', fontsize=20, c='red')
plt.ylabel('$y$', fontsize=20, c='red')
plt.title('$y = cos(x)$', fontsize=25, c='red')
plt.text(9, 0.75, '$cos(x)$', fontsize=12, c='blue')

txt="Figure: This is my Caption"
plt.figtext(0.5, 0, txt, wrap=True, horizontalalignment='center', fontsize=12, c='blue')

plt.show()

# %%
def f(x):
    return (x-3)*(x-5)*(x-7)+85

x = np.linspace(0, 10, 200)
y = f(x)

a, b = 1, 8 # the left and right boundaries
N = 5 # the number of points
xint = np.linspace(a, b, N)
yint = f(xint)

plt.plot(x, y, lw=2)
plt.axis([0, 9, 0, 140])
plt.fill_between(xint, 0, yint, facecolor='gray', alpha=0.4)
plt.text(0.5 * (a + b), 30, r"$\int_a^b f(x)dx$", ha='center', fontsize=20);
plt.show()

# %% [markdown]
# ## Legends, Linestyles, Colors and Markers
#
# Plot $y = 2^x$ an $y = x^2$.

# %%
plt.rc('font', size=10)          # controls default text sizes
plt.rc('axes', titlesize=10)     # fontsize of the axes title
plt.rc('axes', labelsize=12)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=10)    # fontsize of the tick labels
plt.rc('ytick', labelsize=10)    # fontsize of the tick labels
plt.rc('legend', fontsize=10)    # legend fontsize


# Data
x = np.arange(0, 10, 1) # x in [0, 10) 
y_1 = 2 ** x
y_2 = x ** 2

plt.figure()
# Specifying color, linestyle and marker using keyword arguments
plt.plot(x, y_1, label = '$2^x$', color='g', linestyle='--', marker='s')
plt.plot(x, y_2, label = '$x^2$', color='r', linestyle='-', marker='o')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend(loc = 'upper left')
plt.show()

# %% [markdown]
# ## Suplots

# %%
# Data
x = np.arange(0, 6 * np.pi, 0.2)
y_1 = np.cos(x)
y_2 = np.sin(2 * x)

# Plot y = cos(x) 
plt.figure()    ## subplot(nrows, ncols, index, **kwargs)
plt.subplot(2, 1, 1)
plt.plot(x, y_1, label = '$\cos(x)$')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend(loc = 'lower left')

# Plot y = sin(2x)
plt.subplot(2, 1, 2)
plt.plot(x, y_2, label = '$\sin(2x)$')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend(loc = 'lower left')
plt.show()

# %% [markdown]
# ## <b style="color:orange"> Analysis of Figure Object </b>

# %%
def basic_plot(ax):
    x = np.arange(0, 4 * np.pi, 0.1) # x in [0, 4 * pi) 
    y_sin = np.sin(x)

    ax.plot(x, y_sin)
    ax.set_xlabel('$x$', fontsize=15, c='red')
    ax.set_ylabel('$y$', fontsize=15, c='red')
    # ax.legend(loc='lower')

# %%
x = np.arange(-3, 3, 0.1) # x in [0, 4 * pi)
y = x**3

fig, axes = plt.subplots(1,4, figsize = (16,4),tight_layout=True)

for i, ax in enumerate(axes):
    if i <  2: basic_plot(ax)
    if i == 2: 
        axes[i].plot(x, x**3)
        axes[i].set_title('Title', c='red')
    if i == 3: 
        axes[2].plot(x, x**2)

# %%
fig = plt.figure(figsize=(10, 8),tight_layout=True)
# fig.add_subplot(221)

# equivalent but more general
ax1 = fig.add_subplot(2, 2, 1)
basic_plot(ax1)

# add a subplot with no frame
ax2 = fig.add_subplot(222, projection='3d', fc='blue')

# add a polar subplot
fig.add_subplot(223, projection='polar', fc='maroon')

# add a red subplot that share the x-axis with ax1
fig.add_subplot(224, sharex=ax1, facecolor='#FF3399')

# # delete x2 from the figure
# fig.delaxes(ax2)

# # add x2 to the figure again
# fig.add_subplot(ax2)
# Out:
# <AxesSubplot:>

# %%
# fig = plt.figure(figsize=(12, 8))

# # add a subplot with no frame
# ax2 = fig.add_subplot(222, projection='3d', fc='blue')

# # add a polar subplot
# fig.add_subplot(223, projection='polar', fc='maroon')

# ax = Axes3D(fig)

# %%
fig = plt.figure(figsize=(10, 8),tight_layout=True)
gs = fig.add_gridspec(2, 2)

ax1 = fig.add_subplot(gs[0, 0], fc='#FFA500')
ax2 = fig.add_subplot(gs[1, 0], fc='#3399FF') 
# spans two rows:
ax3 = fig.add_subplot(gs[:, 1], fc='#FF0066')

# %%
"""
    If you only want to use a style for a specific block of code but don’t want
    to change the global styling, the style package provides a context manager
    for limiting your changes to a specific scope. To isolate your styling changes,
    you can write something like the following:

"""
with plt.style.context(('dark_background')):
    plt.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o')
plt.show()

# %%
x = np.arange(0, 6 * np.pi, 0.2)
y_1 = np.cos(x)
y_2 = np.sin(2 * x)

# Plot y = cos(x) 
plt.figure()    ## subplot(nrows, ncols, index, **kwargs)
fig, axes = plt.subplots(2,2,figsize = (8, 5))
axes[0,0].plot(x, y_1, label = '$\cos(x)$')
axes[0,0].set_xlabel('$x$')
axes[0,0].set_ylabel('$y$')
axes[0,0].legend(loc = 'upper left')

# %% [markdown]
# ## Multiple y-Axis
#
# Sometimes it is useful to have multiple y-axis in the same plot.
#
# For example, if we want to investigate the corrleation between the obesity rate of a country and the amount of calories that people in this country have per meal.

# %%
# Make-up data
calories = [380.70, 420.98, 454.91, 406.45, 446.16, 498.08, 504.54, 459.05, 459.55, 484.79]
countries = ['India', 'Japan', 'Korea', 'China', 'Thai', 'Italy', 'France', 'Greece', 'Mexico', 'US']
obesity_rates = [3.9, 4.3, 4.7, 6.2, 10, 19.9, 21.6, 24.9, 28.9, 36.2]

fig, ax1 = plt.subplots(figsize = (8, 5))
fig.text(.5, 0, "Figure: This is my Caption", ha='center', fontsize=15)

ax1.bar(countries, obesity_rates, color='C8')
ax1.set_ylabel('obesity rate(%)', color='C8')
ax1.tick_params(axis='y', labelcolor='C8')


ax2 = ax1.twinx()
ax2.plot(countries, calories, color='C0')
ax2.set_ylabel('calories', color='C0')
ax2.tick_params(axis='y', labelcolor='C0')
plt.show()

# %% [markdown]
# ## Shared Axes

# %%
# Data
x = np.arange(0, 6 * np.pi, 0.2)
y_1 = np.cos(x)
y_2 = np.sin(2 * x)
y_3 = y_1 + y_2

fig, axs = plt.subplots(3, 1, sharex = True)
axs[0].plot(x, y_1)
axs[1].plot(x, y_2)
axs[2].plot(x, y_3)
axs[0].set_ylabel('$y$')
axs[1].set_ylabel('$y$')
axs[2].set_ylabel('$y$')
axs[2].set_xlabel('$x$')
plt.show()

# %% [markdown]
# ## Bar Plot

# %%
# Data
x = np.arange(0, 7, 1) # x in [2, 7) 
y = x
 
plt.figure()
plt.bar(x, y, label = '$x$')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend(loc = 'upper left')
plt.show()

# %% [markdown]
# ## Contour Plot
#
#
# A contour plot represents a 3-dimensional surface by plotting constant $z$ slices (contours). Given a value for $z$, lines are drawn for connecting the $(x,y)$ coordinates where that $z$ value occurs.
#
#
# Plot the contours of $J(\mathbf{w})$
#
# $$
# J(\mathbf{w}) = (\mathbf{w} - \mathbf{w}_{o})^{T}\mathbf{A}(\mathbf{w} - \mathbf{w}_{o})
# $$
#
# where $\mathbf{w} = \begin{bmatrix} -2 \\ 2 \end{bmatrix}$, $\mathbf{A} = \begin{bmatrix} 2 & 0 \\ 0 & 1 \end{bmatrix}$.

# %%
xmin, xmax, xstep = -4, 0, .1
ymin, ymax, ystep = 0, 4, .1

A = np.array([[2, 0], [0, 1]])
w0 = np.array([-2., 2.]).reshape(2, 1)

J = lambda x, y: A[0, 0] * (x - w0[0]) ** 2 + (A[0, 1] + A[1, 0]) * (x - w0[0]) * (y - w0[1]) + A[1, 1] * (y - w0[1]) ** 2
gradient_u = lambda x, y: (A[0, 0] * (x - w0[0]) + A[0, 1] * (y - w0[1])) + (A[0, 0] * (x - w0[0]) + A[1, 0] * (y - w0[1]))
gradient_v = lambda x, y: (A[1, 0] * (x - w0[0]) + A[1, 1] * (y - w0[1])) + (A[0, 1] * (x - w0[0]) + A[1, 1] * (y - w0[1]))

x, y = np.meshgrid(np.arange(xmin, xmax + xstep, xstep),
                   np.arange(ymin, ymax + ystep, ystep))

z = J(x, y)

fig, ax = plt.subplots(figsize=(7,7))
ax.contour(x, y, z, levels=np.logspace(0, 5, 35), cmap='jet')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_xlim((xmin, xmax))
ax.set_ylim((ymin, ymax))
plt.show()

# %% [markdown]
# ## Quiver Plot
#
# A quiver plot displays velocity vectors as arrows with components $(u,v)$ at the points $(x,y)$.
#
# Plot $\nabla J(\mathbf{w}) = 2\mathbf{A}\mathbf{w} - 2\mathbf{A}\mathbf{w}_{o}$.

# %%
x1, y1 = np.meshgrid(np.arange(xmin, xmax, 0.2), np.arange(ymin, ymax, 0.2))
u1 = gradient_u(x1, y1)
v1 = gradient_v(x1, y1)

fig, ax = plt.subplots(figsize=(7, 7))
ax.quiver(x1, y1, u1, v1)
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_xlim((xmin, xmax))
ax.set_ylim((ymin, ymax))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(7, 7))
ax.contour(x, y, z, levels=np.logspace(0, 5, 35), cmap='jet')
ax.quiver(x1, y1, u1, v1)
ax.set_xlabel('$x$', c='red', fontsize=20)
ax.set_ylabel('$y$', c='red', fontsize=20)
ax.set_xlim((xmin, xmax))
ax.set_ylim((ymin, ymax))
plt.show()

# %%
fig = plt.figure(figsize = (10,10), tight_layout=True)
ax = fig.gca(projection='3d')

x, y, z = np.meshgrid(np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.8))

u = np.sin(np.pi * x) * np.cos(np.pi * y) * np.cos(np.pi * z)
v = -np.cos(np.pi * x) * np.sin(np.pi * y) * np.cos(np.pi * z)
w = (np.sqrt(2.0 / 3.0) * np.cos(np.pi * x) * np.cos(np.pi * y) *
     np.sin(np.pi * z))

ax.quiver(x, y, z, u, v, w, length=0.1)

plt.show()

# %% [markdown]
# <h2 align=center id="3d"> <a style="color:orange" id="3d">3D Plot</a>

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal

# %% [markdown]
# ## 3D Faces
#
# Besides of contour plot, we can directly plot the 3D faces as well using `matplotlib`.
#
# Plot the 3D-face of 2D [joint Gaussian distribution](https://en.wikipedia.org/wiki/Multivariate_normal_distribution).
#
# $\boldsymbol{\mu}  = \begin{bmatrix} 0 \\ 0 \end{bmatrix} $, $\boldsymbol{\Sigma}  = \begin{bmatrix} 1 & 0 \\ 0 & 1 \end{bmatrix} $.

# %%
fig = plt.figure(figsize = (8,6), tight_layout=True)
ax = plt.axes(projection='3d')
z = np.linspace(0, 30, 100)
x = np.sin(z)
y = np.cos(z)

ax.plot3D(x, y, z);

# %%
mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure(figsize = (10,10))
ax = fig.gca(projection='3d')
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)
ax.plot(x, y, z, label='parametric curve')
ax.legend()

plt.show()

# %%
Mu = np.array([0, 0])
Cov = np.array([[1, 0], [0, 1]])
rv = multivariate_normal(Mu, Cov)

fig = plt.figure(figsize=(8,6),tight_layout=True)
ax = Axes3D(fig)
X = np.arange(-10, 10, 0.25)
Y = np.arange(-10, 10, 0.25)
X, Y = np.meshgrid(X, Y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y
Z = rv.pdf(pos)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.jet)
plt.show()
# Out:
# /Users/a.momin/opt/anaconda3/envs/fastai/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# $\boldsymbol{\mu}  = \begin{bmatrix} 0 \\ 4 \end{bmatrix} $, $\boldsymbol{\Sigma}  = \begin{bmatrix} 5 & 0 \\ 0 & 1 \end{bmatrix} $.

# %%
Mu = np.array([0, 4])
Cov = np.array([[5, 0], [0, 1]])
rv = multivariate_normal(Mu, Cov)

fig = plt.figure(figsize=(12, 8))
ax = Axes3D(fig)
X = np.arange(-10, 10, 0.25)
Y = np.arange(-10, 10, 0.25)
X, Y = np.meshgrid(X, Y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y
Z = rv.pdf(pos)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.jet)
plt.show()

# %% [markdown]
# $\boldsymbol{\mu}  = \begin{bmatrix} 0 \\ 0 \end{bmatrix} $, $\boldsymbol{\Sigma}  = \begin{bmatrix} 10.5 & -9.5 \\ -9.5 & 10.5 \end{bmatrix} $.

# %%
Mu = np.array([0, 0])
Cov = np.array([[10.5, -9.5], [-9.5, 10.5]])
rv = multivariate_normal(Mu, Cov)

fig = plt.figure(figsize=(12, 8))
ax = Axes3D(fig)
X = np.arange(-10, 10, 0.25)
Y = np.arange(-10, 10, 0.25)
X, Y = np.meshgrid(X, Y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y
Z = rv.pdf(pos)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.jet)
plt.show()

# %%
def randrange(n, vmin, vmax):
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111, projection='3d')
n = 100
for c, m, zl, zh in [('r', 'o', -50, -25), ('b', '^', -30, -5)]:
    xs = randrange(n, 23, 32)
    ys = randrange(n, 0, 100)
    zs = randrange(n, zl, zh)
    ax.scatter(xs, ys, zs, c=c, marker=m)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111, projection='3d')
X, Y, Z = axes3d.get_test_data(0.05)
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)

plt.show()

# %%
fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111, projection='3d')

u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)

x = 10 * np.outer(np.cos(u), np.sin(v))
y = 10 * np.outer(np.sin(u), np.sin(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))
ax.plot_surface(x, y, z, rstride=4, cstride=4, color='b')

plt.show()

# %%
fig = plt.figure(figsize = (10,10))
ax = fig.gca(projection='3d')
X, Y, Z = axes3d.get_test_data(0.05)
ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3)
cset = ax.contour(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)

ax.set_xlabel('X')
ax.set_xlim(-40, 40)
ax.set_ylabel('Y')
ax.set_ylim(-40, 40)
ax.set_zlabel('Z')
ax.set_zlim(-100, 100)

plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

fig = plt.figure(figsize=(12, 8))
ax = fig.gca(projection='3d')
X, Y, Z = axes3d.get_test_data(0.05)

# Plot the 3D surface
ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3)

# Plot projections of the contours for each dimension.  By choosing offsets
# that match the appropriate axes limits, the projected contours will sit on
# the 'walls' of the graph
cset = ax.contourf(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)

ax.set_xlim(-40, 40)
ax.set_ylim(-40, 40)
ax.set_zlim(-100, 100)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %%
from matplotlib.collections import PolyCollection
from matplotlib.colors import colorConverter


fig = plt.figure(figsize = (10,10))
ax = fig.gca(projection='3d')


def cc(arg):
    return colorConverter.to_rgba(arg, alpha=0.6)

xs = np.arange(0, 10, 0.4)
verts = []
zs = [0.0, 1.0, 2.0, 3.0]
for z in zs:
    ys = np.random.rand(len(xs))
    ys[0], ys[-1] = 0, 0
    verts.append(list(zip(xs, ys)))

poly = PolyCollection(verts, facecolors=[cc('r'), cc('g'), cc('b'),
                                         cc('y')])
poly.set_alpha(0.7)
ax.add_collection3d(poly, zs=zs, zdir='y')

ax.set_xlabel('X')
ax.set_xlim3d(0, 10)
ax.set_ylabel('Y')
ax.set_ylim3d(-1, 4)
ax.set_zlabel('Z')
ax.set_zlim3d(0, 1)

plt.show()

# %%
fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111, projection='3d')
for c, z in zip(['r', 'g', 'b', 'y'], [30, 20, 10, 0]):
    xs = np.arange(20)
    ys = np.random.rand(20)

    # You can provide either a single color or an array. To demonstrate this,
    # the first bar of each set will be colored cyan.
    cs = [c] * len(xs)
    cs[0] = 'c'
    ax.bar(xs, ys, zs=z, zdir='y', color=cs, alpha=0.8)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %% [markdown]
# ## Color Map

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LogNorm

# %%
X,Y = np.mgrid[0:3, 0:3]
X,Y
# Out:
# (array([[0, 0, 0],
#         [1, 1, 1],
#         [2, 2, 2]]),
#  array([[0, 1, 2],
#         [0, 1, 2],
#         [0, 1, 2]]))

# %%
X2, Y2 = np.meshgrid(np.arange(0,3,1), np.arange(0,3,1))
X2, Y2
# Out:
# (array([[0, 1, 2],
#         [0, 1, 2],
#         [0, 1, 2]]),
#  array([[0, 0, 0],
#         [1, 1, 1],
#         [2, 2, 2]]))

# %%
Z = np.array([[0, 0.5, 1],
              [1, 1.5, 2],
              [2, 2.5, 3]])

# %%
fig, ax = plt.subplots()
ax.imshow(Z)

# %%
plt.pcolormesh(X2, Y2, Z, cmap=plt.cm.PRGn, vmin=-2, vmax=2)
# Out:
# <ipython-input-19-f6eb3e9f5cca>:1: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(X2, Y2, Z, cmap=plt.cm.PRGn, vmin=-2, vmax=2)

# %% [markdown]
# ### A simple pcolor demo:

# %%
Z = np.random.rand(6, 10)
fig = plt.figure(figsize=(8, 6), tight_layout=True)
ax0 = fig.add_subplot(2,1,1)
ax1 = fig.add_subplot(2,1,2)

# fig, (ax0, ax1) = plt.subplots(2, 1)

c = ax0.pcolor(Z)
ax0.set_title('default: no edges')

c = ax1.pcolor(Z, edgecolors='k', linewidths=4)
ax1.set_title('thick edges')

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Comparing pcolor with similar functions:

# %%
# make these smaller to increase the resolution
dx, dy = 0.15, 0.05

# generate 2 2d grids for the x & y bounds
y, x = np.mgrid[slice(-3, 3 + dy, dy),
                slice(-3, 3 + dx, dx)]
z = (1 - x / 2. + x ** 5 + y ** 3) * np.exp(-x ** 2 - y ** 2)
# x and y are bounds, so z should be the value *inside* those bounds.
# Therefore, remove the last value from the z array.
z = z[:-1, :-1]
z_min, z_max = -np.abs(z).max(), np.abs(z).max()

fig, axs = plt.subplots(2, 2)

ax = axs[0, 0]
c = ax.pcolor(x, y, z, cmap='RdBu', vmin=z_min, vmax=z_max)
ax.set_title('pcolor')
fig.colorbar(c, ax=ax)

ax = axs[0, 1]
c = ax.pcolormesh(x, y, z, cmap='RdBu', vmin=z_min, vmax=z_max)
ax.set_title('pcolormesh')
fig.colorbar(c, ax=ax)

ax = axs[1, 0]
c = ax.imshow(z, cmap='RdBu', vmin=z_min, vmax=z_max,
              extent=[x.min(), x.max(), y.min(), y.max()],
              interpolation='nearest', origin='lower')
ax.set_title('image (nearest)')
fig.colorbar(c, ax=ax)

ax = axs[1, 1]
c = ax.pcolorfast(x, y, z, cmap='RdBu', vmin=z_min, vmax=z_max)
ax.set_title('pcolorfast')
fig.colorbar(c, ax=ax)

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Box Plot

# %% [markdown]
# In this example we use the dataset [California Housing Prices](https://www.kaggle.com/camnugent/california-housing-prices), which contains information from the 1990 California census. `seaborn`, a high-level API based on `matplotlib`, is also used.
#
# A box plot shows the interquartile range, midhinge, range, mid-range, and trimean of the data. Dots the whiskers are outliers.

# %%
# !ls /Users/a.momin/Data

# %%
data =  '/Users/a.momin/Data/housing.csv'
df = pd.read_csv(data, nrows=500)
df
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.23     37.88                41.0        880.0           129.0
# 1      -122.22     37.86                21.0       7099.0          1106.0
# 2      -122.24     37.85                52.0       1467.0           190.0
# 3      -122.25     37.85                52.0       1274.0           235.0
# 4      -122.25     37.85                52.0       1627.0           280.0
# ..         ...       ...                 ...          ...             ...
# 495    -122.25     37.86                52.0       4048.0           663.0
# 496    -122.26     37.85                52.0       3618.0           768.0
# 497    -122.27     37.85                52.0       4076.0           920.0
# 498    -122.27     37.85                47.0       2077.0           400.0
# 499    -122.27     37.85                50.0       1279.0           300.0
#
#      population  households  median_income  median_house_value ocean_proximity
# ...

# %%
df[0:5]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(data=df, x = 'total_bedrooms', y = 'median_house_value', palette = 'viridis')
plt.show()

# %% [markdown]
# ## Correlation Matrix [Heatmap](https://matplotlib.org/stable/gallery/images_contours_and_fields/image_annotated_heatmap.html#sphx-glr-gallery-images-contours-and-fields-image-annotated-heatmap-py)

# %%
data = '~/Data/housing.csv'
df = pd.read_csv(data, nrows=500)
df = df.dropna()

# %%
plt.figure(figsize=(10, 6), tight_layout=True)
sns.heatmap(cbar=False, annot=True, data=df.corr(), cmap='coolwarm')
plt.title('Correlation Matrix', fontsize=25, c='navy')
plt.show()

# %% [markdown]
# ## IPython Widgets
#
# Plot $ y = \cos(\omega_1 x) + \cos(\omega_2 x)$. $\omega_1$ and $\omega_2$ are controlled by sliders.

# %%
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets 

@widgets.interact(s1=(1, 30.0), s2=(1, 30.0), continuous_update=False)
def f(s1, s2):
    plt.figure()
    x = np.arange(0, 20 * np.pi, 0.1)
    y = np.cos(s1 * x) + np.cos(s2 * x)
    plt.plot(x, y)
    plt.show()
# Out:
# interactive(children=(FloatSlider(value=15.5, description='s1', max=30.0, min=1.0), FloatSlider(value=15.5, de…

# %% [markdown]
# ## Matplotlib Widgets
#
# If you want to use sliders outside notebooks, `matplotlib` provides an option for you. Copy the follow block of code to a `.py` file and run it.
#
# The following example plots $ y = \cos(\omega_1 x) + \cos(\omega_2 x)$. $\omega_1$ and $\omega_2$ are controlled by sliders.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider

x = np.arange(0, 20 * np.pi, 0.1)
y = np.cos(3 * x) + np.cos(5 * x)

fig, ax = plt.subplots()  
plt.subplots_adjust(bottom=0.2,left=0.3) 
l, = plt.plot(x, y)

om1= plt.axes([0.25, 0.1, 0.65, 0.03]) 
om2 = plt.axes([0.25, 0.15, 0.65, 0.03]) 

som1 = Slider(om1, r'$\omega_1$', 1, 30.0, valinit=3) 
som2 = Slider(om2, r'$\omega_2$', 1, 30.0, valinit=5)

def update(val):
    s1 = som1.val
    s2 = som2.val
    x = np.arange(0, 20 * np.pi, 0.1)
    y = np.cos(s1 * x) + np.cos(s2 * x)
    l.set_ydata(y)
    l.set_xdata(x)

som1.on_changed(update)
som2.on_changed(update)

plt.show()

# %% [markdown]
# ## [Overview of seaborn plotting functions](https://seaborn.pydata.org/tutorial/function_overview.html)

# %% [markdown]
# - [Seaborn Tutorial](https://seaborn.pydata.org/tutorial.html)

# %%
sns.set_theme(color_codes=True)
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")

# %%
iris.drop(columns=['species', 'petal_width'], inplace=True)

# %%
sns.kdeplot(data=iris)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.regplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="size", y="tip", data=tips, x_estimator=np.mean);

# %% [markdown]
# # [Plotnine (ggplot)](https://realpython.com/ggplot-python/#setting-up-your-environment):

# %%
from plotnine import *
from plotnine.data import *

# %matplotlib inline

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
(
    ggplot(mpg, aes(x='displ', y='hwy'))
    + geom_point()
    + geom_smooth()
)
# Out:
# <ggplot: (315144292)>

# %%
# Gallery Plot

(
    ggplot(mpg, aes(x='displ', y='hwy', color='factor(drv)'))
    + geom_point()
    + geom_smooth(method='lm')
    + labs(x='displacement', y='horsepower')
)
# Out:
# <ggplot: (306060551)>
